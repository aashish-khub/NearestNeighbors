# %% [markdown]
# # Testing Dataloader Interface

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from nearest_neighbors.dataloader_factory import NNData

# %%
HS_data = NNData.create('heartsteps')

# %%
Data, Mask = HS_data.process_data_scalar()
# Out:
# Processing HeartSteps V1...

# %%
from matplotlib.pyplot import matshow

matshow(Mask, aspect="auto")
