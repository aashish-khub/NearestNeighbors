# %% [markdown]
# # Heartsteps Data Transformation

# %% [markdown]
# We transform the Heartsteps v1 data to satisfy two primary criterion: (1) alignment of study day and decision slot across users and (2) restructuring of the data to match the distributional nearest neighbors framework. More information about this structure can be found later in the notebook.

# %% [markdown]
# ## Import libraries and load data

# %%
import pandas as pd
import numpy as np
import os
data_dir = "data"
os.makedirs(data_dir, exist_ok=True)
output_dir = "out"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# The `jbsteps.csv` file contains step data for (roughly) every minute that trial partipants were wearing their Jawbone step tracker. We select the columns of interest and index the dataframe by the user index and the time that steps were recorded.

# %%
# load in the 5 minute observations
df_steps = pd.read_csv(os.path.join(data_dir,"jbsteps.csv"))
df_steps = df_steps[["user.index", "steps.utime", "steps", "study.day.nogap"]]
df_steps["steps.utime"] = pd.to_datetime(df_steps["steps.utime"])
#creeate multi-index
df_steps = df_steps.set_index(['user.index', 'steps.utime'])

# %% [markdown]
# The `suggestions.csv` file contains data for each notification slot during all user trials. There are 5 notification slots per day.

# %%
df_suggestions = pd.read_csv(os.path.join(data_dir, "suggestions.csv"))
# Out:
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1658104724.py:1: DtypeWarning: Columns (21,22,38,39,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_suggestions = pd.read_csv("data/suggestions.csv")

# %% [markdown]
# We select the columns of interest and drop rows containing nan for crucial columns.

# %%
df_sugg_sel = df_suggestions[["user.index", 'decision.index.nogap', 'sugg.select.utime','sugg.decision.utime', 'sugg.select.slot', 'avail', 'send', 'send.active', 'send.sedentary']]
df_sugg_sel['sugg.decision.utime'] = pd.to_datetime(df_sugg_sel['sugg.decision.utime'])
df_sugg_sel = df_sugg_sel.dropna(subset=["sugg.decision.utime", "sugg.select.utime", "user.index"])
df_sugg_sel
# Out:
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/3018626082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sugg_sel['sugg.decision.utime'] = pd.to_datetime(df_sugg_sel['sugg.decision.utime'])
#       user.index  decision.index.nogap    sugg.select.utime  \
# 0              1                   0.0  2015-07-22 16:30:00
# 1              1                   1.0  2015-07-22 18:30:00
# 2              1                   2.0  2015-07-22 21:30:00
# 3              1                   3.0  2015-07-22 23:30:00
# 4              1                   4.0  2015-07-23 09:30:00
# ...          ...                   ...                  ...
# 8269          37                 225.0  2016-01-26 00:02:00
# 8270          37                 226.0  2016-01-26 13:00:00
# 8271          37                 227.0  2016-01-26 16:26:00
# 8272          37                 228.0  2016-01-26 19:00:00
# 8273          37                 229.0  2016-01-26 22:25:00
#
#      sugg.decision.utime  sugg.select.slot  avail   send send.active  \
# 0    2015-07-22 16:31:53                 2   True   True       False
# 1    2015-07-22 18:32:10                 3   True   True        True
# 2    2015-07-22 21:31:48                 4   True  False       False
# 3    2015-07-22 23:31:50                 5   True   True       False
# 4    2015-07-23 09:31:31                 1   True  False       False
# ...                  ...               ...    ...    ...         ...
# 8269 2016-01-26 00:03:36                 5   True  False       False
# 8270 2016-01-26 13:01:04                 1  False  False       False
# 8271 2016-01-26 16:27:50                 2   True   True        True
# 8272 2016-01-26 19:02:09                 3   True   True       False
# 8273 2016-01-26 22:27:07                 4   True   True       False
#
#      send.sedentary
# 0              True
# 1             False
# 2             False
# 3              True
# 4             False
# ...             ...
# 8269          False
# 8270          False
# 8271          False
# 8272           True
# 8273           True
#
# [8273 rows x 9 columns]

# %% [markdown]
# Next, we group the step observations into 5 minute chunks.

# %%
def get_mode(x):
  if len(pd.Series.mode(x) > 1):
    return pd.Series.mode(x, dropna=False)[0]
  else:
    return pd.Series.mode(x, dropna=False)

df_5min = df_steps.groupby([pd.Grouper(freq='5min', level = "steps.utime", label = "right"), 
pd.Grouper(level = "user.index")], sort = False).agg({'steps': 'sum', 'study.day.nogap': lambda x : get_mode(x)}).reset_index()
df_5min
# Out:
#               steps.utime  user.index  steps  study.day.nogap
# 0     2015-07-22 14:55:00           1     19              NaN
# 1     2015-07-22 15:00:00           1    163              NaN
# 2     2015-07-22 15:05:00           1     58              NaN
# 3     2015-07-22 15:10:00           1      2              NaN
# 4     2015-07-22 15:15:00           1     61              NaN
# ...                   ...         ...    ...              ...
# 98524 2016-01-26 21:20:00          37     23             46.0
# 98525 2016-01-26 21:25:00          37     57             46.0
# 98526 2016-01-26 21:35:00          37     67             46.0
# 98527 2016-01-26 21:45:00          37     20             46.0
# 98528 2016-01-26 22:00:00          37     27             46.0
#
# [98529 rows x 4 columns]

# %% [markdown]
# Now, we expand the time periods to include all times of day, not just the times that steps were measured.
# This is necessary as step data collection often occured in spurts. This means that time periods in which a notification was sent may not be represented in the original data frame, making it difficult to merge `df_suggestions` and `df_5min`. Time periods where steps were not tracked are imputed with 0 steps. This may not accurately represent the user's real step count in that period, but it is a limitation imposed by the data. Future work may fold in the Google Steps tracking information, which is more complete but potentially inaccurate approximation of user step activity.

# %%
# fill out the 5 minute intervals between measurements
from datetime import date, timedelta
def reind_id(df_u):
    rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1), 
    normalize = True, inclusive = "both", freq = "5T")
    rng = rng[rng.indexer_between_time('00:00', '23:55')]
    #print(rng)
    df_reind = df_u.reindex(rng)
    df_reind['user.index'] = df_reind['user.index'].ffill().bfill()
    df_reind['study.day.nogap'] = df_reind['study.day.nogap'].bfill().ffill()
    df_reind['steps'] = df_reind['steps'].fillna(0)
    return df_reind

df_5min_ind = df_5min.set_index('steps.utime')

df_expand5min = df_5min_ind.groupby('user.index', group_keys = False).apply(lambda df_u:reind_id(df_u))
df_expand5min = df_expand5min.reset_index(names = "steps.utime")

df_expand5min['user.index'] = df_expand5min['user.index'].astype("int64")
print(df_expand5min)
# Out:
#                steps.utime  user.index  steps  study.day.nogap
# 0      2015-07-22 00:00:00           1    0.0              0.0
# 1      2015-07-22 00:05:00           1    0.0              0.0
# 2      2015-07-22 00:10:00           1    0.0              0.0
# 3      2015-07-22 00:15:00           1    0.0              0.0
# 4      2015-07-22 00:20:00           1    0.0              0.0
# ...                    ...         ...    ...              ...
# 492512 2016-01-26 23:40:00          37    0.0             46.0
# 492513 2016-01-26 23:45:00          37    0.0             46.0
# 492514 2016-01-26 23:50:00          37    0.0             46.0
# 492515 2016-01-26 23:55:00          37    0.0             46.0
# 492516 2016-01-27 00:00:00          37    0.0             46.0
#
# [492517 rows x 4 columns]
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   rng = pd.date_range(min(df_u.index.astype('datetime64[ns]')), max(df_u.index.astype('datetime64[ns]')) + timedelta(days = 1),
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/1173640391.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_expand5min = df_5min_ind.groupby('user.index', group_keys = False).apply(lambda df_u:reind_id(df_u))

# %% [markdown]
# Next, we merge `df_sugg_sel` with `df_expand5min`. The merge will provide notification information for each decision slot. Notifications are grouped into the 5 minute block that occurs after the decision was made. For example, a decision made at 8:31:50 AM would be joined with the 8:35 AM time slot.

# %%
# merge as of on steps.utime with the time of each notification time period. by = user.index, tolerance = pd.Timedelta("5min"), check for direction
df_merged = pd.merge_asof(
    df_expand5min.sort_values(by ='steps.utime'),
    df_sugg_sel.sort_values(by = 'sugg.decision.utime'),
    left_on="steps.utime",
    right_on="sugg.decision.utime",
    by="user.index",
    tolerance=pd.Timedelta("5min"),
    allow_exact_matches=False,
    direction = 'backward'
).sort_values(by = ["user.index", "steps.utime"]).reset_index(drop = True)

#df_merged[df_merged["user.index"] == 1][df_merged["sugg.select.utime"] == "2015-09-15 10:30:00"]
#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #display(df_merged[df_merged['user.index'] == 36][7000:7150])
    
# want to treat vacation days as maximally normal observation periods -> they are not notification periods
df_merged['sugg.select.slot'] = np.where(df_merged['decision.index.nogap'].isna(), np.nan, df_merged['sugg.select.slot'])
display(df_merged)
# Out:
#                steps.utime  user.index  steps  study.day.nogap  \
# 0      2015-07-22 00:00:00           1    0.0              0.0
# 1      2015-07-22 00:05:00           1    0.0              0.0
# 2      2015-07-22 00:10:00           1    0.0              0.0
# 3      2015-07-22 00:15:00           1    0.0              0.0
# 4      2015-07-22 00:20:00           1    0.0              0.0
# ...                    ...         ...    ...              ...
# 492512 2016-01-26 23:40:00          37    0.0             46.0
# 492513 2016-01-26 23:45:00          37    0.0             46.0
# 492514 2016-01-26 23:50:00          37    0.0             46.0
# 492515 2016-01-26 23:55:00          37    0.0             46.0
# 492516 2016-01-27 00:00:00          37    0.0             46.0
#
#         decision.index.nogap sugg.select.utime sugg.decision.utime  \
# 0                        NaN               NaN                 NaT
# 1                        NaN               NaN                 NaT
# 2                        NaN               NaN                 NaT
# 3                        NaN               NaN                 NaT
# 4                        NaN               NaN                 NaT
# ...                      ...               ...                 ...
# 492512                   NaN               NaN                 NaT
# 492513                   NaN               NaN                 NaT
# 492514                   NaN               NaN                 NaT
# 492515                   NaN               NaN                 NaT
# 492516                   NaN               NaN                 NaT
#
#         sugg.select.slot avail send send.active send.sedentary
# 0                    NaN   NaN  NaN         NaN            NaN
# 1                    NaN   NaN  NaN         NaN            NaN
# 2                    NaN   NaN  NaN         NaN            NaN
# 3                    NaN   NaN  NaN         NaN            NaN
# 4                    NaN   NaN  NaN         NaN            NaN
# ...                  ...   ...  ...         ...            ...
# 492512               NaN   NaN  NaN         NaN            NaN
# 492513               NaN   NaN  NaN         NaN            NaN
# 492514               NaN   NaN  NaN         NaN            NaN
# 492515               NaN   NaN  NaN         NaN            NaN
# 492516               NaN   NaN  NaN         NaN            NaN
#
# [492517 rows x 12 columns]

# %% [markdown]
# We take 12 rows after each decision period. This represents 1 hour of step data following each (potential) notification. We drop duplicate rows as some notifications fell within one hour of each other, creating overlapping time ranges.

# %%
df_merged.iloc[np.argsort(pd.notna(df_merged['sugg.select.slot']), )]
# Out:
#                steps.utime  user.index  steps  study.day.nogap  \
# 0      2015-07-22 00:00:00           1    0.0              0.0
# 327071 2015-12-10 13:55:00          25    0.0             15.0
# 327070 2015-12-10 13:50:00          25    0.0             15.0
# 327069 2015-12-10 13:45:00          25   40.0             15.0
# 327068 2015-12-10 13:40:00          25    0.0             15.0
# ...                    ...         ...    ...              ...
# 234726 2015-11-07 23:05:00          18   36.0             26.0
# 436371 2016-01-16 01:35:00          33   19.0             35.0
# 371824 2015-11-15 23:05:00          28    0.0             24.0
# 221201 2015-10-24 00:05:00          17   62.0             22.0
# 480421 2015-12-16 00:05:00          37    0.0              4.0
#
#         decision.index.nogap    sugg.select.utime sugg.decision.utime  \
# 0                        NaN                  NaN                 NaT
# 327071                   NaN                  NaN                 NaT
# 327070                   NaN                  NaN                 NaT
# 327069                   NaN                  NaN                 NaT
# 327068                   NaN                  NaN                 NaT
# ...                      ...                  ...                 ...
# 234726                 130.0  2015-11-07 23:00:00 2015-11-07 23:04:02
# 436371                 178.0  2016-01-16 01:30:00 2016-01-16 01:31:37
# 371824                 120.0  2015-11-15 23:00:00 2015-11-15 23:01:35
# 221201                 112.0  2015-10-24 00:00:00 2015-10-24 00:02:38
# 480421                  20.0  2015-12-16 00:00:00 2015-12-16 00:01:50
#
#         sugg.select.slot avail   send send.active send.sedentary
# 0                    NaN   NaN    NaN         NaN            NaN
# 327071               NaN   NaN    NaN         NaN            NaN
# 327070               NaN   NaN    NaN         NaN            NaN
# 327069               NaN   NaN    NaN         NaN            NaN
# 327068               NaN   NaN    NaN         NaN            NaN
# ...                  ...   ...    ...         ...            ...
# 234726               4.0  True  False       False          False
# 436371               5.0  True   True        True          False
# 371824               4.0  True   True        True          False
# 221201               5.0  True   True        True          False
# 480421               5.0  True   True        True          False
#
# [492517 rows x 12 columns]

# %%
# grab 12 rows after each notification period
def takeRange(df: pd.DataFrame, range: int): 
  idx = df.index.get_indexer_for(df[(pd.notna(np.argsort(df["sugg.select.slot"])))].index)
  ranges = [np.arange(i, min(i + range + 1, len(df))) for i in idx]
  #print("Next Df")
  # for i in ranges:
  #  num_overlap = len(df.iloc[i][pd.notna(df['sugg.select.slot'])])
  #  if (num_overlap > 1):
  #   print("Overlap: ") 
  #   print(df.iloc[i])
  return df.iloc[np.concatenate(ranges)]
# find ids of the notification period -> this only happens when sugg.select.slot is not na
#idx = df_merged.index.get_indexer_for(df_merged[pd.notna(df_merged['sugg.select.slot'])].index)
# we want 1 hour of data after the notification period, so 12 slots
#df_merged.iloc[np.unique(np.concatenate([np.arange(i, min(i+n+1, len(df_merged)))
                                            #for i in idx]))]
df_merged_cut = df_merged.groupby('user.index', group_keys = False).apply(lambda df_u:takeRange(df_u, 12)).reset_index(drop = True)
df_merged_cut_nd = df_merged_cut.drop_duplicates()

# set up column for study day
df_merged_cut_nd['study_day'] = np.nan
df_merged_cut_nd['new_slot'] = np.nan

#with pd.option_context('display.max_rows', None, 'display.max_columns', None):
# 1130 2015-07-22 08:10:00           1    0.0              0.0
# 1143 2015-07-22 08:15:00           1    0.0              0.0
#
#       decision.index.nogap sugg.select.utime sugg.decision.utime  \
# 0                      NaN               NaN                 NaT
# 1                      NaN               NaN                 NaT
# 2                      NaN               NaN                 NaT
# 3                      NaN               NaN                 NaT
# 4                      NaN               NaN                 NaT
# 5                      NaN               NaN                 NaT
# 6                      NaN               NaN                 NaT
# 7                      NaN               NaN                 NaT
# 8                      NaN               NaN                 NaT
# 9                      NaN               NaN                 NaT
# 10                     NaN               NaN                 NaT
# 11                     NaN               NaN                 NaT
# 12                     NaN               NaN                 NaT
# 25                     NaN               NaN                 NaT
# 38                     NaN               NaN                 NaT
# 51                     NaN               NaN                 NaT
# 64                     NaN               NaN                 NaT
# 77                     NaN               NaN                 NaT
# 90                     NaN               NaN                 NaT
# 103                    NaN               NaN                 NaT
# 116                    NaN               NaN                 NaT
# 129                    NaN               NaN                 NaT
# 142                    NaN               NaN                 NaT
# 155                    NaN               NaN                 NaT
# 168                    NaN               NaN                 NaT
# 181                    NaN               NaN                 NaT
# 194                    NaN               NaN                 NaT
# 207                    NaN               NaN                 NaT
# 220                    NaN               NaN                 NaT
# 233                    NaN               NaN                 NaT
# 246                    NaN               NaN                 NaT
# 259                    NaN               NaN                 NaT
# 272                    NaN               NaN                 NaT
# 285                    NaN               NaN                 NaT
# 298                    NaN               NaN                 NaT
# 311                    NaN               NaN                 NaT
# 324                    NaN               NaN                 NaT
# 337                    NaN               NaN                 NaT
# 350                    NaN               NaN                 NaT
# 363                    NaN               NaN                 NaT
# 376                    NaN               NaN                 NaT
# 389                    NaN               NaN                 NaT
# 402                    NaN               NaN                 NaT
# 415                    NaN               NaN                 NaT
# 428                    NaN               NaN                 NaT
# 441                    NaN               NaN                 NaT
# 454                    NaN               NaN                 NaT
# 467                    NaN               NaN                 NaT
# 480                    NaN               NaN                 NaT
# 493                    NaN               NaN                 NaT
# 506                    NaN               NaN                 NaT
# 519                    NaN               NaN                 NaT
# 532                    NaN               NaN                 NaT
# 545                    NaN               NaN                 NaT
# 558                    NaN               NaN                 NaT
# 571                    NaN               NaN                 NaT
# 584                    NaN               NaN                 NaT
# 597                    NaN               NaN                 NaT
# 610                    NaN               NaN                 NaT
# 623                    NaN               NaN                 NaT
# 636                    NaN               NaN                 NaT
# 649                    NaN               NaN                 NaT
# 662                    NaN               NaN                 NaT
# 675                    NaN               NaN                 NaT
# 688                    NaN               NaN                 NaT
# 701                    NaN               NaN                 NaT
# 714                    NaN               NaN                 NaT
# 727                    NaN               NaN                 NaT
# 740                    NaN               NaN                 NaT
# 753                    NaN               NaN                 NaT
# 766                    NaN               NaN                 NaT
# 779                    NaN               NaN                 NaT
# 792                    NaN               NaN                 NaT
# 805                    NaN               NaN                 NaT
# 818                    NaN               NaN                 NaT
# 831                    NaN               NaN                 NaT
# 844                    NaN               NaN                 NaT
# 857                    NaN               NaN                 NaT
# 870                    NaN               NaN                 NaT
# 883                    NaN               NaN                 NaT
# 896                    NaN               NaN                 NaT
# 909                    NaN               NaN                 NaT
# 922                    NaN               NaN                 NaT
# 935                    NaN               NaN                 NaT
# 948                    NaN               NaN                 NaT
# 961                    NaN               NaN                 NaT
# 974                    NaN               NaN                 NaT
# 987                    NaN               NaN                 NaT
# 1000                   NaN               NaN                 NaT
# 1013                   NaN               NaN                 NaT
# 1026                   NaN               NaN                 NaT
# 1039                   NaN               NaN                 NaT
# 1052                   NaN               NaN                 NaT
# 1065                   NaN               NaN                 NaT
# 1078                   NaN               NaN                 NaT
# 1091                   NaN               NaN                 NaT
# 1104                   NaN               NaN                 NaT
# 1117                   NaN               NaN                 NaT
# 1130                   NaN               NaN                 NaT
# 1143                   NaN               NaN                 NaT
#
#       sugg.select.slot avail send send.active send.sedentary  study_day  \
# 0                  NaN   NaN  NaN         NaN            NaN        NaN
# 1                  NaN   NaN  NaN         NaN            NaN        NaN
# 2                  NaN   NaN  NaN         NaN            NaN        NaN
# 3                  NaN   NaN  NaN         NaN            NaN        NaN
# 4                  NaN   NaN  NaN         NaN            NaN        NaN
# 5                  NaN   NaN  NaN         NaN            NaN        NaN
# 6                  NaN   NaN  NaN         NaN            NaN        NaN
# 7                  NaN   NaN  NaN         NaN            NaN        NaN
# 8                  NaN   NaN  NaN         NaN            NaN        NaN
# 9                  NaN   NaN  NaN         NaN            NaN        NaN
# 10                 NaN   NaN  NaN         NaN            NaN        NaN
# 11                 NaN   NaN  NaN         NaN            NaN        NaN
# 12                 NaN   NaN  NaN         NaN            NaN        NaN
# 25                 NaN   NaN  NaN         NaN            NaN        NaN
# 38                 NaN   NaN  NaN         NaN            NaN        NaN
# 51                 NaN   NaN  NaN         NaN            NaN        NaN
# 64                 NaN   NaN  NaN         NaN            NaN        NaN
# 77                 NaN   NaN  NaN         NaN            NaN        NaN
# 90                 NaN   NaN  NaN         NaN            NaN        NaN
# 103                NaN   NaN  NaN         NaN            NaN        NaN
# 116                NaN   NaN  NaN         NaN            NaN        NaN
# 129                NaN   NaN  NaN         NaN            NaN        NaN
# 142                NaN   NaN  NaN         NaN            NaN        NaN
# 155                NaN   NaN  NaN         NaN            NaN        NaN
# 168                NaN   NaN  NaN         NaN            NaN        NaN
# 181                NaN   NaN  NaN         NaN            NaN        NaN
# 194                NaN   NaN  NaN         NaN            NaN        NaN
# 207                NaN   NaN  NaN         NaN            NaN        NaN
# 220                NaN   NaN  NaN         NaN            NaN        NaN
# 233                NaN   NaN  NaN         NaN            NaN        NaN
# 246                NaN   NaN  NaN         NaN            NaN        NaN
# 259                NaN   NaN  NaN         NaN            NaN        NaN
# 272                NaN   NaN  NaN         NaN            NaN        NaN
# 285                NaN   NaN  NaN         NaN            NaN        NaN
# 298                NaN   NaN  NaN         NaN            NaN        NaN
# 311                NaN   NaN  NaN         NaN            NaN        NaN
# 324                NaN   NaN  NaN         NaN            NaN        NaN
# 337                NaN   NaN  NaN         NaN            NaN        NaN
# 350                NaN   NaN  NaN         NaN            NaN        NaN
# 363                NaN   NaN  NaN         NaN            NaN        NaN
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 25         NaN
# 38         NaN
# 51         NaN
# 64         NaN
# 77         NaN
# 90         NaN
# 103        NaN
# 116        NaN
# 129        NaN
# 142        NaN
# 155        NaN
# 168        NaN
# 181        NaN
# 194        NaN
# 207        NaN
# 220        NaN
# 233        NaN
# 246        NaN
# 259        NaN
# 272        NaN
# 285        NaN
# 298        NaN
# 311        NaN
# 324        NaN
# 337        NaN
# 350        NaN
# 363        NaN
# 376        NaN
# 389        NaN
# 402        NaN
# 415        NaN
# 428        NaN
# 441        NaN
# 454        NaN
# 467        NaN
# 480        NaN
# 493        NaN
# 506        NaN
# 519        NaN
# 532        NaN
# 545        NaN
# 558        NaN
# 571        NaN
# 584        NaN
# 597        NaN
# 610        NaN
# 623        NaN
# 636        NaN
# 649        NaN
# 662        NaN
# 675        NaN
# 688        NaN
# 701        NaN
# 714        NaN
# 727        NaN
# 740        NaN
# 753        NaN
# 766        NaN
# 779        NaN
# 792        NaN
# 805        NaN
# 818        NaN
# 831        NaN
# 844        NaN
# 857        NaN
# 870        NaN
# 883        NaN
# 896        NaN
# 909        NaN
# 922        NaN
# 935        NaN
# 948        NaN
# 961        NaN
# 974        NaN
# 987        NaN
# 1000       NaN
# 1013       NaN
# 1026       NaN
# 1039       NaN
# 1052       NaN
# 1065       NaN
# 1078       NaN
# 1091       NaN
# 1104       NaN
# 1117       NaN
# 1130       NaN
# 1143       NaN

# %% [markdown]
# We artificially "fix" the decision slots and study day columns. The adjustments done below counteract abnormalities in the data, such as a notification scheduled to sent at slot 4 but was instead sent at slot 1. The need for a new study day column arises from mismatches in time between recorded steps and the notifications. Since study days were only measured explicitly alongside recorded steps, the notifications would often have the incorrect study day if multiple notifications were sent before any steps were recorded. To reduce these study day miscalculations, we manually create new decision slots based on the existing patterns and base study days entirely on a sequence of 5 decision slots.

# %%
def create_slots(df):
  most_rec_slot = 0.0
  for ind, row in df.iterrows():
    curr_slot = row['sugg.select.slot']
    if not np.isnan(curr_slot):
      if most_rec_slot != 5.0 and curr_slot != most_rec_slot + 1 and most_rec_slot != 0.0:
        df.at[ind, 'new_slot'] = most_rec_slot + 1
        most_rec_slot += 1
      elif most_rec_slot == 5.0 and curr_slot != 1:
        df.at[ind, 'new_slot'] = 1
        most_rec_slot = 1
      else:
        df.at[ind, 'new_slot'] = curr_slot
        most_rec_slot = curr_slot
      #print(curr_study_day)
      #df.at[ind,'study_day'] = curr_study_day
      #print(df.loc[ind]['study_day'])
  return df
def study_day(df):
  most_rec_slot = 1.0
  curr_study_day = 1
  for ind, row in df.iterrows():
    curr_slot = row['new_slot']
    if not np.isnan(curr_slot):
      if most_rec_slot == 5.0 and curr_slot == 1:
        curr_study_day += 1
      most_rec_slot = curr_slot
      #print(curr_study_day)
      df.at[ind,'study_day'] = curr_study_day

  return df
df_slot = df_merged_cut_nd.groupby('user.index', group_keys = False).apply(lambda df_u: create_slots(df_u))
df_study_day = df_slot.groupby('user.index', group_keys = False).apply(lambda df_u: study_day(df_u))
# Out:
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/3362100768.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_slot = df_merged_cut_nd.groupby('user.index', group_keys = False).apply(lambda df_u: create_slots(df_u))
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/3362100768.py:33: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_study_day = df_slot.groupby('user.index', group_keys = False).apply(lambda df_u: study_day(df_u))

# %%
df_slot
# Out:
#                 steps.utime  user.index  steps  study.day.nogap  \
# 0       2015-07-22 00:00:00           1    0.0              0.0
# 1       2015-07-22 00:05:00           1    0.0              0.0
# 2       2015-07-22 00:10:00           1    0.0              0.0
# 3       2015-07-22 00:15:00           1    0.0              0.0
# 4       2015-07-22 00:20:00           1    0.0              0.0
# ...                     ...         ...    ...              ...
# 6399704 2016-01-26 23:40:00          37    0.0             46.0
# 6399717 2016-01-26 23:45:00          37    0.0             46.0
# 6399730 2016-01-26 23:50:00          37    0.0             46.0
# 6399743 2016-01-26 23:55:00          37    0.0             46.0
# 6399756 2016-01-27 00:00:00          37    0.0             46.0
#
#          decision.index.nogap sugg.select.utime sugg.decision.utime  \
# 0                         NaN               NaN                 NaT
# 1                         NaN               NaN                 NaT
# 2                         NaN               NaN                 NaT
# 3                         NaN               NaN                 NaT
# 4                         NaN               NaN                 NaT
# ...                       ...               ...                 ...
# 6399704                   NaN               NaN                 NaT
# 6399717                   NaN               NaN                 NaT
# 6399730                   NaN               NaN                 NaT
# 6399743                   NaN               NaN                 NaT
# 6399756                   NaN               NaN                 NaT
#
#          sugg.select.slot avail send send.active send.sedentary  study_day  \
# 0                     NaN   NaN  NaN         NaN            NaN        NaN
# 1                     NaN   NaN  NaN         NaN            NaN        NaN
# 2                     NaN   NaN  NaN         NaN            NaN        NaN
# 3                     NaN   NaN  NaN         NaN            NaN        NaN
# 4                     NaN   NaN  NaN         NaN            NaN        NaN
# ...                   ...   ...  ...         ...            ...        ...
# 6399704               NaN   NaN  NaN         NaN            NaN        NaN
# 6399717               NaN   NaN  NaN         NaN            NaN        NaN
# 6399730               NaN   NaN  NaN         NaN            NaN        NaN
# 6399743               NaN   NaN  NaN         NaN            NaN        NaN
# 6399756               NaN   NaN  NaN         NaN            NaN        NaN
#
#          new_slot
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6399704       NaN
# 6399717       NaN
# 6399730       NaN
# 6399743       NaN
# 6399756       NaN
#
# [492517 rows x 14 columns]

# %%
df_slot[(df_slot["sugg.select.slot"] != df_slot["new_slot"]) & pd.notna(df_slot["avail"])]
# Out:
#                 steps.utime  user.index  steps  study.day.nogap  \
# 80131   2015-08-12 10:35:00           1   52.0             20.0
# 81067   2015-08-12 16:35:00           1   52.0             20.0
# 81379   2015-08-12 18:35:00           1    0.0             20.0
# 81847   2015-08-12 21:35:00           1    0.0             20.0
# 82159   2015-08-12 23:35:00           1    0.0             20.0
# ...                     ...         ...    ...              ...
# 5242587 2016-01-08 19:45:00          31    0.0              5.0
# 5243029 2016-01-08 22:35:00          31   50.0              5.0
# 5243263 2016-01-09 00:05:00          31  137.0              5.0
# 6091656 2015-12-28 16:35:00          36    0.0             15.0
# 6091864 2015-12-28 17:55:00          36    0.0             15.0
#
#          decision.index.nogap    sugg.select.utime sugg.decision.utime  \
# 80131                     NaN  2015-08-12 10:30:00 2015-08-12 10:31:23
# 81067                     NaN  2015-08-12 16:30:00 2015-08-12 16:32:06
# 81379                     NaN  2015-08-12 18:30:00 2015-08-12 18:32:07
# 81847                     NaN  2015-08-12 21:30:00 2015-08-12 21:31:08
# 82159                     NaN  2015-08-12 23:30:00 2015-08-12 23:30:56
# ...                       ...                  ...                 ...
# 5242587                   NaN  2016-01-08 19:40:00 2016-01-08 19:41:30
# 5243029                   NaN  2016-01-08 22:30:00 2016-01-08 22:31:30
# 5243263                   NaN  2016-01-09 00:00:00 2016-01-09 00:01:47
# 6091656                  74.0  2015-12-28 16:30:00 2015-12-28 16:31:30
# 6091864                  73.0  2015-12-28 14:30:00 2015-12-28 17:53:15
#
#          sugg.select.slot  avail   send send.active send.sedentary  study_day  \
# 80131                 NaN   True   True       False           True        NaN
# 81067                 NaN   True   True       False           True        NaN
# 81379                 NaN   True   True        True          False        NaN
# 81847                 NaN  False  False       False          False        NaN
# 82159                 NaN   True   True       False           True        NaN
# ...                   ...    ...    ...         ...            ...        ...
# 5242587               NaN  False    NaN       False          False        NaN
# 5243029               NaN  False    NaN       False          False        NaN
# 5243263               NaN   True  False       False          False        NaN
# 6091656               2.0  False    NaN       False          False        NaN
# 6091864               1.0   True   True        True          False        NaN
#
#          new_slot
# 80131         NaN
# 81067         NaN
# 81379         NaN
# 81847         NaN
# 82159         NaN
# ...           ...
# 5242587       NaN
# 5243029       NaN
# 5243263       NaN
# 6091656       1.0
# 6091864       2.0
#
# [404 rows x 14 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  display(df_study_day[(df_study_day['user.index'] == 1) & (pd.notna(df_study_day['avail']))])
# Out:
#                steps.utime  user.index  steps  study.day.nogap  \
# 2443   2015-07-22 16:35:00           1    0.0              0.0
# 2755   2015-07-22 18:35:00           1  142.0              0.0
# 3223   2015-07-22 21:35:00           1   70.0              0.0
# 3535   2015-07-22 23:35:00           1  195.0              0.0
# 5095   2015-07-23 09:35:00           1    0.0              1.0
# 6187   2015-07-23 16:35:00           1  204.0              1.0
# 6499   2015-07-23 18:35:00           1  184.0              1.0
# 6967   2015-07-23 21:35:00           1  412.0              1.0
# 7279   2015-07-23 23:35:00           1    0.0              1.0
# 8839   2015-07-24 09:35:00           1    0.0              2.0
# 9931   2015-07-24 16:35:00           1   21.0              2.0
# 10243  2015-07-24 18:35:00           1   64.0              2.0
# 10711  2015-07-24 21:35:00           1  490.0              2.0
# 11023  2015-07-24 23:35:00           1    0.0              2.0
# 12596  2015-07-25 09:40:00           1    0.0              3.0
# 13675  2015-07-25 16:35:00           1   82.0              3.0
# 13987  2015-07-25 18:35:00           1  268.0              3.0
# 14455  2015-07-25 21:35:00           1  183.0              3.0
# 201655                 167.0  2015-09-13 21:30:00 2015-09-13 21:31:54
# 201967                 168.0  2015-09-13 23:30:00 2015-09-13 23:31:51
# 203683                 169.0  2015-09-14 10:30:00 2015-09-14 10:31:05
# 204619                 170.0  2015-09-14 16:30:00 2015-09-14 16:32:20
# 204931                 171.0  2015-09-14 18:30:00 2015-09-14 18:32:33
# 205399                 172.0  2015-09-14 21:30:00 2015-09-14 21:31:30
# 205711                 173.0  2015-09-14 23:30:00 2015-09-14 23:31:41
#
#         sugg.select.slot  avail   send send.active send.sedentary  study_day  \
# 2443                 2.0   True   True       False           True        1.0
# 2755                 3.0   True   True        True          False        1.0
# 3223                 4.0   True  False       False          False        1.0
# 3535                 5.0   True   True       False           True        1.0
# 5095                 1.0   True  False       False          False        2.0
# 6187                 2.0   True   True       False           True        2.0
# 6499                 3.0   True   True        True          False        2.0
# 6967                 4.0   True   True        True          False        2.0
# 7279                 5.0   True  False       False          False        2.0
# 8839                 1.0   True  False       False          False        3.0
# 9931                 2.0   True   True       False           True        3.0
# 10243                3.0   True   True       False           True        3.0
# 10711                4.0   True   True        True          False        3.0
# 11023                5.0   True  False       False          False        3.0
# 12596                1.0   True   True        True          False        4.0
# 13675                2.0   True   True        True          False        4.0
# 13987                3.0   True   True        True          False        4.0
# 14455                4.0   True  False       False          False        4.0
# 14767                5.0  False  False       False          False        4.0
# 16327                1.0   True   True        True          False        5.0
# 17419                2.0   True   True        True          False        5.0
# 17731                3.0   True   True       False           True        5.0
# 18199                4.0   True   True        True          False        5.0
# 18511                5.0   True  False       False          False        5.0
# 20071                1.0   True  False       False          False        6.0
# 21163                2.0   True  False       False          False        6.0
# 21475                3.0   True   True       False           True        6.0
# 21943                4.0   True  False       False          False        6.0
# 22255                5.0  False  False       False          False        6.0
# 23815                1.0   True   True       False           True        7.0
# 24907                2.0   True   True        True          False        7.0
# 25219                3.0   True   True        True          False        7.0
# 25687                4.0   True   True       False           True        7.0
# 25999                5.0   True  False       False          False        7.0
# 27715                1.0   True  False       False          False        8.0
# 28651                2.0   True   True       False           True        8.0
# 28963                3.0   True   True       False           True        8.0
# 29431                4.0   True   True       False           True        8.0
# 29743                5.0   True  False       False          False        8.0
# 31459                1.0   True  False       False          False        9.0
# 32395                2.0   True   True        True          False        9.0
# 32707                3.0   True   True       False           True        9.0
# 33175                4.0   True   True       False           True        9.0
# 33487                5.0   True   True       False           True        9.0
# 35203                1.0   True   True        True          False       10.0
# 36139                2.0  False  False       False          False       10.0
# 36451                3.0   True   True        True          False       10.0
# 36919                4.0   True  False       False          False       10.0
# 37231                5.0   True   True        True          False       10.0
# 38947                1.0   True   True        True          False       11.0
# 39883                2.0   True   True        True          False       11.0
# 40195                3.0   True  False       False          False       11.0
# 40663                4.0   True   True        True          False       11.0
# 40975                5.0   True   True        True          False       11.0
# 42691                1.0   True   True        True          False       12.0
# 43627                2.0   True   True       False           True       12.0
# 43939                3.0   True  False       False          False       12.0
# 44407                4.0   True  False       False          False       12.0
# 44719                5.0   True   True       False           True       12.0
# 46435                1.0   True   True       False           True       13.0
# 47371                2.0   True   True        True          False       13.0
# 47683                3.0   True   True        True          False       13.0
# 48151                4.0   True   True        True          False       13.0
# 48463                5.0   True   True        True          False       13.0
# 50179                1.0   True   True       False           True       14.0
# 51115                2.0   True  False       False          False       14.0
# 51427                3.0   True  False       False          False       14.0
# 51895                4.0   True  False       False          False       14.0
# 52207                5.0  False  False       False          False       14.0
# 53923                1.0   True  False       False          False       15.0
# 54859                2.0   True  False       False          False       15.0
# 55171                3.0   True   True       False           True       15.0
# 55639                4.0   True  False       False          False       15.0
# 55951                5.0   True  False       False          False       15.0
# 57667                1.0   True  False       False          False       16.0
# 58603                2.0   True   True        True          False       16.0
# 58915                3.0   True  False       False          False       16.0
# 59383                4.0   True   True       False           True       16.0
# 59695                5.0   True   True       False           True       16.0
# 61411                1.0   True   True       False           True       17.0
# 62347                2.0   True   True        True          False       17.0
# 62659                3.0   True   True        True          False       17.0
# 63127                4.0   True   True       False           True       17.0
# 63439                5.0   True   True        True          False       17.0
# 65155                1.0   True  False       False          False       18.0
# 66091                2.0   True   True        True          False       18.0
# 66403                3.0   True   True       False           True       18.0
# 66871                4.0   True   True       False           True       18.0
# 67183                5.0   True  False       False          False       18.0
# 68899                1.0   True   True        True          False       19.0
# 69835                2.0   True  False       False          False       19.0
# 70147                3.0   True   True       False           True       19.0
# 70615                4.0   True   True        True          False       19.0
# 70927                5.0   True  False       False          False       19.0
# 72643                1.0   True   True        True          False       20.0
# 73579                2.0   True   True       False           True       20.0
# 73891                3.0   True  False       False          False       20.0
# 74359                4.0   True  False       False          False       20.0
# 74684                5.0   True  False       False          False       20.0
# 76387                1.0   True   True        True          False       21.0
# 77323                2.0   True  False       False          False       21.0
# 77635                3.0   True   True        True          False       21.0
# 78103                4.0   True  False       False          False       21.0
# 78428                5.0   True  False       False          False       21.0
# 80131                NaN   True   True       False           True        NaN
# 81067                NaN   True   True       False           True        NaN
# 81379                NaN   True   True        True          False        NaN
# 81847                NaN  False  False       False          False        NaN
# 82159                NaN   True   True       False           True        NaN
# 83875                NaN   True   True        True          False        NaN
# 84811                NaN   True   True        True          False        NaN
# 85123                NaN   True   True        True          False        NaN
# 85591                NaN   True   True        True          False        NaN
# 85903                NaN   True  False       False          False        NaN
# 87619                NaN   True  False       False          False        NaN
# 88555                NaN   True   True        True          False        NaN
# 88867                NaN   True  False       False          False        NaN
# 89335                NaN   True  False       False          False        NaN
# 89647                NaN   True  False       False          False        NaN
# 91363                NaN   True  False       False          False        NaN
# 92299                NaN   True   True        True          False        NaN
# ...
# 107275               NaN   True   True        True          False        NaN
# 107587               NaN   True   True       False           True        NaN
# 108055               NaN   True   True        True          False        NaN
# 108367               NaN   True   True        True          False        NaN
# 110083               NaN  False  False       False          False        NaN
# 111032               NaN   True   True       False           True        NaN
# 111331               NaN   True   True        True          False        NaN
# 111799               NaN   True  False       False          False        NaN
# 112111               NaN  False  False       False          False        NaN
# 113827               NaN   True   True       False           True        NaN
# 114763               NaN   True   True        True          False        NaN
# 115075               NaN   True   True        True          False        NaN
# 115543               NaN   True   True       False           True        NaN
# 115855               NaN   True   True       False           True        NaN
# 117571               NaN   True  False       False          False        NaN
# 118507               NaN   True   True       False           True        NaN
# 118819               NaN   True   True        True          False        NaN
# 119287               NaN   True   True       False           True        NaN
# 119599               NaN   True  False       False          False        NaN
# 121315               NaN   True  False       False          False        NaN
# 122251               NaN   True   True        True          False        NaN
# 122563               NaN   True   True       False           True        NaN
# 123031               NaN   True  False       False          False        NaN
# 123343               NaN   True   True       False           True        NaN
# 125059               NaN  False  False       False          False        NaN
# 125995               NaN   True  False       False          False        NaN
# 126307               NaN   True  False       False          False        NaN
# 126775               NaN   True   True        True          False        NaN
# 127087               NaN   True  False       False          False        NaN
# 128803               NaN  False    NaN       False          False        NaN
# 129739               NaN   True   True       False           True        NaN
# 130051               NaN   True  False       False          False        NaN
# 130519               NaN   True   True       False           True        NaN
# 130831               NaN   True   True       False           True        NaN
# 132547               NaN   True   True        True          False        NaN
# 133483               NaN   True  False       False          False        NaN
# 133795               NaN   True  False       False          False        NaN
# 134263               NaN   True  False       False          False        NaN
# 134575               NaN   True   True       False           True        NaN
# 136291               NaN   True   True        True          False        NaN
# 137227               NaN   True  False       False          False        NaN
# 137539               NaN   True  False       False          False        NaN
# 138007               NaN   True  False       False          False        NaN
# 138319               NaN   True   True       False           True        NaN
# 140035               NaN  False    NaN       False          False        NaN
# 140971               NaN   True   True       False           True        NaN
# 141283               NaN   True   True        True          False        NaN
# 141751               NaN   True  False       False          False        NaN
# 142063               NaN   True  False       False          False        NaN
# 143779               NaN   True   True        True          False        NaN
# 144715               NaN   True  False       False          False        NaN
# 145027               NaN   True  False       False          False        NaN
# 145495               NaN   True   True       False           True        NaN
# 145807               NaN   True   True       False           True        NaN
# 147523               NaN   True   True       False           True        NaN
# 148459               NaN   True  False       False          False        NaN
# 148771               NaN   True   True        True          False        NaN
# 149239               NaN  False  False       False          False        NaN
# 149551               NaN  False    NaN       False          False        NaN
# 151267               NaN   True  False       False          False        NaN
# 152203               NaN   True  False       False          False        NaN
# 152515               NaN   True   True        True          False        NaN
# 152983               NaN   True  False       False          False        NaN
# 153295               NaN   True   True       False           True        NaN
# 155011               1.0   True  False       False          False       22.0
# 155947               2.0   True   True       False           True       22.0
# 156259               3.0   True   True       False           True       22.0
# 156727               4.0   True  False       False          False       22.0
# 157039               5.0   True   True       False           True       22.0
# 158755               1.0   True  False       False          False       23.0
# 159691               2.0   True  False       False          False       23.0
# 160003               3.0   True   True       False           True       23.0
# 160471               4.0   True   True       False           True       23.0
# 160783               5.0   True   True        True          False       23.0
# 162499               1.0   True   True        True          False       24.0
# 163435               2.0   True   True       False           True       24.0
# 163747               3.0   True  False       False          False       24.0
# 164215               4.0   True  False       False          False       24.0
# 164527               5.0   True   True        True          False       24.0
# 166243               1.0   True   True        True          False       25.0
# 167179               2.0   True  False       False          False       25.0
# 167491               3.0   True   True        True          False       25.0
# 167959               4.0   True   True        True          False       25.0
# 168271               5.0   True  False       False          False       25.0
# 170000               1.0   True  False       False          False       26.0
# 170923               2.0   True  False       False          False       26.0
# 171235               3.0   True   True       False           True       26.0
# 171703               4.0  False  False       False          False       26.0
# 172015               5.0   True   True       False           True       26.0
# 173731               1.0   True  False       False          False       27.0
# 174667               2.0   True  False       False          False       27.0
# 174979               3.0   True   True       False           True       27.0
# 175447               4.0   True   True        True          False       27.0
# 175759               5.0   True  False       False          False       27.0
# 177475               1.0  False    NaN       False          False       28.0
# 178411               2.0   True   True        True          False       28.0
# 178723               3.0   True   True       False           True       28.0
# 179191               4.0   True  False       False          False       28.0
# 179503               5.0   True   True       False           True       28.0
# 181219               1.0  False  False       False          False       29.0
# 182155               2.0   True  False       False          False       29.0
# 182467               3.0   True  False       False          False       29.0
# 182935               4.0   True   True        True          False       29.0
# 183247               5.0   True   True        True          False       29.0
# 184963               1.0   True   True       False           True       30.0
# 185899               2.0   True   True       False           True       30.0
# 186211               3.0   True   True       False           True       30.0
# 186679               4.0   True   True       False           True       30.0
# 186991               5.0   True  False       False          False       30.0
# 188707               1.0   True   True        True          False       31.0
# 189643               2.0   True   True       False           True       31.0
# 189955               3.0   True   True        True          False       31.0
# 190423               4.0  False  False       False          False       31.0
# 190735               5.0   True   True       False           True       31.0
# 192451               1.0   True   True       False           True       32.0
# 193387               2.0  False  False       False          False       32.0
# 193699               3.0  False  False       False          False       32.0
# 194167               4.0   True   True        True          False       32.0
# 194479               5.0   True   True        True          False       32.0
# 196195               1.0   True  False       False          False       33.0
# 197131               2.0   True  False       False          False       33.0
# 197443               3.0   True  False       False          False       33.0
# 197911               4.0  False  False       False          False       33.0
# 198223               5.0   True   True       False           True       33.0
# 199939               1.0   True  False       False          False       34.0
# 200875               2.0   True  False       False          False       34.0
# 201187               3.0   True  False       False          False       34.0
# 201655               4.0   True  False       False          False       34.0
# 201967               5.0   True  False       False          False       34.0
# 203683               1.0   True  False       False          False       35.0
# 204619               2.0   True   True       False           True       35.0
# 204931               3.0   True   True       False           True       35.0
# 205399               4.0   True  False       False          False       35.0
# 205711               5.0   True   True       False           True       35.0
#
#         new_slot
# 2443         2.0
# 2755         3.0
# 3223         4.0
# 3535         5.0
# 5095         1.0
# 6187         2.0
# 6499         3.0
# 6967         4.0
# 7279         5.0
# 8839         1.0
# 9931         2.0
# 10243        3.0
# 10711        4.0
# 11023        5.0
# 12596        1.0
# 13675        2.0
# 13987        3.0
# 14455        4.0
# 14767        5.0
# 16327        1.0
# 17419        2.0
# 17731        3.0
# 18199        4.0
# 18511        5.0
# 20071        1.0
# 21163        2.0
# 21475        3.0
# 21943        4.0
# 22255        5.0
# 23815        1.0
# 24907        2.0
# 25219        3.0
# 25687        4.0
# 25999        5.0
# 27715        1.0
# 28651        2.0
# 28963        3.0
# 29431        4.0
# 29743        5.0
# 31459        1.0
# 32395        2.0
# 32707        3.0
# 33175        4.0
# 33487        5.0
# 35203        1.0
# 36139        2.0
# 36451        3.0
# 36919        4.0
# 37231        5.0
# 38947        1.0
# 39883        2.0
# 40195        3.0
# 40663        4.0
# 40975        5.0
# 42691        1.0
# 43627        2.0
# 43939        3.0
# 44407        4.0
# 44719        5.0
# 46435        1.0
# 47371        2.0
# 47683        3.0
# 48151        4.0
# 48463        5.0
# 50179        1.0
# 51115        2.0
# 51427        3.0
# 51895        4.0
# 52207        5.0
# 53923        1.0
# 54859        2.0
# 55171        3.0
# 55639        4.0
# 55951        5.0
# 57667        1.0
# 58603        2.0
# 58915        3.0
# 59383        4.0
# 59695        5.0
# 61411        1.0
# 62347        2.0
# 62659        3.0
# 63127        4.0
# 63439        5.0
# 65155        1.0
# 66091        2.0
# 66403        3.0
# 66871        4.0
# 67183        5.0
# 68899        1.0
# 69835        2.0
# 70147        3.0
# 70615        4.0
# 70927        5.0
# 72643        1.0
# 73579        2.0
# 73891        3.0
# 74359        4.0
# 74684        5.0
# 76387        1.0
# 77323        2.0
# 77635        3.0
# 78103        4.0
# 78428        5.0
# 80131        NaN
# 81067        NaN
# 81379        NaN
# 81847        NaN
# 82159        NaN
# 83875        NaN
# 84811        NaN
# 85123        NaN
# 85591        NaN
# 85903        NaN
# 87619        NaN
# 88555        NaN
# 88867        NaN
# 89335        NaN
# 89647        NaN
# 91363        NaN
# 92299        NaN
# 92611        NaN
# 93079        NaN
# 93391        NaN
# 95107        NaN
# 96043        NaN
# 96355        NaN
# 96823        NaN
# 97135        NaN
# 98851        NaN
# 99787        NaN
# 100099       NaN
# 100567       NaN
# 100879       NaN
# 102595       NaN
# 103531       NaN
# 103843       NaN
# 104311       NaN
# 104623       NaN
# 106339       NaN
# 107275       NaN
# 107587       NaN
# 108055       NaN
# 108367       NaN
# 110083       NaN
# 111032       NaN
# 111331       NaN
# 111799       NaN
# 112111       NaN
# 113827       NaN
# 114763       NaN
# 115075       NaN
# 115543       NaN
# 115855       NaN
# 117571       NaN
# 118507       NaN
# 118819       NaN
# 119287       NaN
# 119599       NaN
# 121315       NaN
# 122251       NaN
# 122563       NaN
# 123031       NaN
# 123343       NaN
# 125059       NaN
# 125995       NaN
# 126307       NaN
# 126775       NaN
# 127087       NaN
# 128803       NaN
# 129739       NaN
# 130051       NaN
# 130519       NaN
# 130831       NaN
# 132547       NaN
# 133483       NaN
# 133795       NaN
# 134263       NaN
# 134575       NaN
# 136291       NaN
# 137227       NaN
# 137539       NaN
# 138007       NaN
# 138319       NaN
# 140035       NaN
# 140971       NaN
# 141283       NaN
# 141751       NaN
# 142063       NaN
# 143779       NaN
# 144715       NaN
# 145027       NaN
# 145495       NaN
# 145807       NaN
# 147523       NaN
# 148459       NaN
# 148771       NaN
# 149239       NaN
# 149551       NaN
# 151267       NaN
# 152203       NaN
# 152515       NaN
# 152983       NaN
# 153295       NaN
# 155011       1.0
# 155947       2.0
# 156259       3.0
# 156727       4.0
# 157039       5.0
# 158755       1.0
# 159691       2.0
# 160003       3.0
# 160471       4.0
# 160783       5.0
# 162499       1.0
# 163435       2.0
# 163747       3.0
# 164215       4.0
# 164527       5.0
# 166243       1.0
# 167179       2.0
# 167491       3.0
# 167959       4.0
# 168271       5.0
# 170000       1.0
# 170923       2.0
# 171235       3.0
# 171703       4.0
# 172015       5.0
# 173731       1.0
# 174667       2.0
# 174979       3.0
# 175447       4.0
# 175759       5.0
# 177475       1.0
# 178411       2.0
# 178723       3.0
# 179191       4.0
# 179503       5.0
# 181219       1.0
# 182155       2.0
# 182467       3.0
# 182935       4.0
# 183247       5.0
# 184963       1.0
# 185899       2.0
# 186211       3.0
# 186679       4.0
# 186991       5.0
# 188707       1.0
# 189643       2.0
# 189955       3.0
# 190423       4.0
# 190735       5.0
# 192451       1.0
# 193387       2.0
# 193699       3.0
# 194167       4.0
# 194479       5.0
# 196195       1.0
# 197131       2.0
# 197443       3.0
# 197911       4.0
# 198223       5.0
# 199939       1.0
# 200875       2.0
# 201187       3.0
# 201655       4.0
# 201967       5.0
# 203683       1.0
# 204619       2.0
# 204931       3.0
# 205399       4.0
# 205711       5.0

# %% [markdown]
# We find the maximum study day so that we can pad the remaining trials to that study period. We also set the index of the final data frame as a combination of the user index, study day, and the decision slot of the day. In theory, this index is unique.

# %%
# find the max study day
print(max(df_study_day['study.day.nogap']))
print(df_study_day['study_day'].max())

#print(max_study_day)
df_final = df_study_day.set_index(['user.index', 'study_day', 'new_slot'])
# Out:
# 51.0
# 52.0

# %% [markdown]
# In `transform_dnn`, we iteratively search for the set of measurements for each user x study day x day decision slot combination. If such a measurement exists, the missingness of the data is determined by whether or not a notification was sent. If it does not, the missingness could either be treated as the user not being available (A = 2) or the data not being observed (A = 0). Further, we only use `send.sedentary` as an indicator of treatment. Future work could combine `send.sedentary` and `send.active`. TODO: several questions here

# %%
def transform_dnn(df, users = 37, max_study_day = 52, day_dec = 5, num_measurements = 12):
  """

  """
  final_M = np.zeros((users, max_study_day, day_dec, num_measurements))
  final_A = np.zeros((users, max_study_day, day_dec))
  for user in range(1, users + 1):
    for day in range(1, max_study_day + 1):
      for slot in range(1, day_dec + 1):
        try:
          df_uds = df.loc[user, day, slot]
          ind = df.index.get_indexer_for(df_uds.index)
          if len(ind) > 1:
            print(ind)
            display(df.iloc[ind])
          df_rng = df.iloc[np.arange(ind, min(ind + num_measurements, len(df)))]
          if df.iloc[ind]['avail'].bool():
            # only take send.sedentary as the treatment indicator, could use send.active later
            val = df.iloc[ind]["send.sedentary"]
            if len(val) >1:
              print(val)
            conv_val = val if val.notna().bool() else df.iloc[ind]["send"]
            final_A[user - 1,day - 1, slot - 1] = int(conv_val)
          else:
            final_A[user - 1, day - 1, slot - 1] = 2

          measurements = df_rng['steps'].to_numpy()
          if len(measurements) == num_measurements:
            final_M[user - 1, day - 1, slot - 1] = measurements
          else:
            m_pad = np.pad(measurements, (0, num_measurements -  len(measurements)),
            constant_values = np.nan)
            final_M[user - 1, day - 1, slot - 1] = m_pad
        except KeyError as e:
          # this user is missing the study day/day ind
          print(repr(e))
          final_A[user - 1, day - 1, slot - 1] = 0 # do we consider missing data as not observed or not available
          final_M[user - 1, day - 1, slot - 1] = np.full(num_measurements, np.nan)
  final_M = final_M.reshape((users, max_study_day * day_dec, num_measurements))
  final_A = final_A.reshape((users, max_study_day * day_dec))
  return final_M, final_A

# %% [markdown]
# Finally, we transform the data and show the masking matrix to see the missingness pattern.

# %%
#df_final.loc[1, 20, 1.0]
M_hs, A_hs = transform_dnn(df_final)
# Out:
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/4123529684.py:11: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_uds = df.loc[user, day, slot]
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/4123529684.py:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   df_rng = df.iloc[np.arange(ind, min(ind + num_measurements, len(df)))]
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/4123529684.py:17: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   if df.iloc[ind]['avail'].bool():
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/4123529684.py:22: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   conv_val = val if val.notna().bool() else df.iloc[ind]["send"]
# /var/folders/hq/d_cm2qx12gb3r62jcvshbth80000gp/T/ipykernel_97138/4123529684.py:23: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   final_A[user - 1,day - 1, slot - 1] = int(conv_val)
# KeyError((1, 1, 1))
# KeyError((1, 36, 1))
# KeyError((1, 36, 2))
# KeyError((1, 36, 3))
# KeyError((1, 36, 4))
# KeyError((1, 36, 5))
# KeyError((1, 37, 1))
# KeyError((1, 37, 2))
# KeyError((1, 37, 3))
# KeyError((1, 37, 4))
# KeyError((1, 37, 5))
# KeyError((1, 38, 1))
# KeyError((1, 38, 2))
# KeyError((1, 38, 3))
# KeyError((1, 38, 4))
# KeyError((1, 38, 5))
# KeyError((1, 39, 1))
# KeyError((1, 39, 2))
# KeyError((1, 39, 3))
# KeyError((1, 39, 4))
# KeyError((1, 39, 5))
# KeyError((1, 40, 1))
# KeyError((1, 40, 2))
# KeyError((1, 40, 3))
# KeyError((1, 40, 4))
# KeyError((1, 40, 5))
# KeyError((1, 41, 1))
# KeyError((1, 41, 2))
# KeyError((1, 41, 3))
# KeyError((1, 41, 4))
# KeyError((1, 41, 5))
# KeyError((1, 42, 1))
# KeyError((1, 42, 2))
# KeyError((1, 42, 3))
# KeyError((1, 42, 4))
# KeyError((1, 42, 5))
# KeyError((1, 43, 1))
# KeyError((1, 43, 2))
# KeyError((1, 43, 3))
# KeyError((1, 43, 4))
# KeyError((1, 43, 5))
# KeyError((1, 44, 1))
# KeyError((1, 44, 2))
# KeyError((1, 44, 3))
# KeyError((1, 44, 4))
# KeyError((1, 44, 5))
# KeyError((1, 45, 1))
# KeyError((1, 45, 2))
# KeyError((1, 45, 3))
# KeyError((1, 45, 4))
# KeyError((1, 45, 5))
# KeyError((1, 46, 1))
# KeyError((1, 46, 2))
# KeyError((1, 46, 3))
# KeyError((1, 46, 4))
# KeyError((1, 46, 5))
# KeyError((1, 47, 1))
# KeyError((1, 47, 2))
# KeyError((1, 47, 3))
# KeyError((1, 47, 4))
# KeyError((1, 47, 5))
# KeyError((1, 48, 1))
# KeyError((1, 48, 2))
# KeyError((1, 48, 3))
# KeyError((1, 48, 4))
# KeyError((1, 48, 5))
# KeyError((1, 49, 1))
# KeyError((1, 49, 2))
# KeyError((1, 49, 3))
# KeyError((1, 49, 4))
# KeyError((1, 49, 5))
# KeyError((1, 50, 1))
# KeyError((1, 50, 2))
# KeyError((1, 50, 3))
# KeyError((1, 50, 4))
# KeyError((1, 50, 5))
# KeyError((1, 51, 1))
# KeyError((1, 51, 2))
# KeyError((1, 51, 3))
# KeyError((1, 51, 4))
# KeyError((1, 51, 5))
# KeyError((1, 52, 1))
# KeyError((1, 52, 2))
# KeyError((1, 52, 3))
# KeyError((1, 52, 4))
# KeyError((1, 52, 5))
# KeyError((2, 1, 1))
# KeyError((2, 43, 1))
# KeyError((2, 43, 2))
# KeyError((2, 43, 3))
# KeyError((2, 43, 4))
# KeyError((2, 43, 5))
# KeyError((2, 44, 1))
# KeyError((2, 44, 2))
# KeyError((2, 44, 3))
# KeyError((2, 44, 4))
# KeyError((2, 44, 5))
# KeyError((2, 45, 1))
# KeyError((2, 45, 2))
# KeyError((2, 45, 3))
# KeyError((2, 45, 4))
# KeyError((2, 45, 5))
# KeyError((2, 46, 1))
# KeyError((2, 46, 2))
# KeyError((2, 46, 3))
# KeyError((2, 46, 4))
# KeyError((2, 46, 5))
# KeyError((2, 47, 1))
# KeyError((2, 47, 2))
# KeyError((2, 47, 3))
# KeyError((2, 47, 4))
# KeyError((2, 47, 5))
# KeyError((2, 48, 1))
# KeyError((2, 48, 2))
# KeyError((2, 48, 3))
# KeyError((2, 48, 4))
# KeyError((2, 48, 5))
# KeyError((2, 49, 1))
# KeyError((2, 49, 2))
# KeyError((2, 49, 3))
# KeyError((2, 49, 4))
# KeyError((2, 49, 5))
# KeyError((2, 50, 1))
# KeyError((2, 50, 2))
# KeyError((2, 50, 3))
# KeyError((2, 50, 4))
# KeyError((2, 50, 5))
# KeyError((2, 51, 1))
# KeyError((2, 51, 2))
# KeyError((2, 51, 3))
# KeyError((2, 51, 4))
# KeyError((2, 51, 5))
# KeyError((2, 52, 1))
# KeyError((2, 52, 2))
# KeyError((2, 52, 3))
# KeyError((2, 52, 4))
# KeyError((2, 52, 5))
# KeyError((3, 1, 1))
# KeyError((3, 1, 2))
# KeyError((3, 44, 3))
# KeyError((3, 44, 4))
# KeyError((3, 44, 5))
# KeyError((3, 45, 1))
# KeyError((3, 45, 2))
# KeyError((3, 45, 3))
# KeyError((3, 45, 4))
# KeyError((3, 45, 5))
# KeyError((3, 46, 1))
# KeyError((3, 46, 2))
# KeyError((3, 46, 3))
# KeyError((3, 46, 4))
# KeyError((3, 46, 5))
# KeyError((3, 47, 1))
# KeyError((3, 47, 2))
# KeyError((3, 47, 3))
# KeyError((3, 47, 4))
# KeyError((3, 47, 5))
# KeyError((3, 48, 1))
# KeyError((3, 48, 2))
# KeyError((3, 48, 3))
# KeyError((3, 48, 4))
# KeyError((3, 48, 5))
# KeyError((3, 49, 1))
# KeyError((3, 49, 2))
# KeyError((3, 49, 3))
# KeyError((3, 49, 4))
# KeyError((3, 49, 5))
# KeyError((3, 50, 1))
# KeyError((3, 50, 2))
# KeyError((3, 50, 3))
# KeyError((3, 50, 4))
# KeyError((3, 50, 5))
# KeyError((3, 51, 1))
# KeyError((3, 51, 2))
# KeyError((3, 51, 3))
# KeyError((3, 51, 4))
# KeyError((3, 51, 5))
# KeyError((3, 52, 1))
# KeyError((3, 52, 2))
# KeyError((3, 52, 3))
# KeyError((3, 52, 4))
# KeyError((3, 52, 5))
# KeyError((4, 1, 1))
# KeyError((4, 1, 2))
# KeyError((4, 45, 1))
# KeyError((4, 45, 2))
# KeyError((4, 45, 3))
# KeyError((4, 45, 4))
# KeyError((4, 45, 5))
# KeyError((4, 46, 1))
# KeyError((4, 46, 2))
# KeyError((4, 46, 3))
# KeyError((4, 46, 4))
# KeyError((4, 46, 5))
# KeyError((4, 47, 1))
# KeyError((4, 47, 2))
# KeyError((4, 47, 3))
# KeyError((4, 47, 4))
# KeyError((4, 47, 5))
# KeyError((4, 48, 1))
# KeyError((4, 48, 2))
# KeyError((4, 48, 3))
# KeyError((4, 48, 4))
# KeyError((4, 48, 5))
# KeyError((4, 49, 1))
# KeyError((4, 49, 2))
# KeyError((4, 49, 3))
# KeyError((4, 49, 4))
# KeyError((4, 49, 5))
# KeyError((4, 50, 1))
# KeyError((4, 50, 2))
# KeyError((4, 50, 3))
# KeyError((4, 50, 4))
# KeyError((4, 50, 5))
# KeyError((4, 51, 1))
# KeyError((4, 51, 2))
# KeyError((4, 51, 3))
# KeyError((4, 51, 4))
# KeyError((4, 51, 5))
# KeyError((4, 52, 1))
# KeyError((4, 52, 2))
# KeyError((4, 52, 3))
# KeyError((4, 52, 4))
# KeyError((4, 52, 5))
# KeyError((5, 1, 1))
# KeyError((5, 1, 2))
# KeyError((5, 44, 5))
# KeyError((5, 45, 1))
# KeyError((5, 45, 2))
# KeyError((5, 45, 3))
# KeyError((5, 45, 4))
# KeyError((5, 45, 5))
# KeyError((5, 46, 1))
# KeyError((5, 46, 2))
# KeyError((5, 46, 3))
# KeyError((5, 46, 4))
# KeyError((5, 46, 5))
# KeyError((5, 47, 1))
# KeyError((5, 47, 2))
# KeyError((5, 47, 3))
# KeyError((5, 47, 4))
# KeyError((5, 47, 5))
# KeyError((5, 48, 1))
# KeyError((5, 48, 2))
# KeyError((5, 48, 3))
# KeyError((5, 48, 4))
# KeyError((5, 48, 5))
# KeyError((5, 49, 1))
# KeyError((5, 49, 2))
# KeyError((5, 49, 3))
# KeyError((5, 49, 4))
# KeyError((5, 49, 5))
# KeyError((5, 50, 1))
# KeyError((5, 50, 2))
# KeyError((5, 50, 3))
# KeyError((5, 50, 4))
# KeyError((5, 50, 5))
# KeyError((5, 51, 1))
# KeyError((5, 51, 2))
# KeyError((5, 51, 3))
# KeyError((5, 51, 4))
# KeyError((5, 51, 5))
# KeyError((5, 52, 1))
# KeyError((5, 52, 2))
# KeyError((5, 52, 3))
# KeyError((5, 52, 4))
# KeyError((5, 52, 5))
# KeyError((6, 1, 1))
# KeyError((6, 1, 2))
# KeyError((6, 1, 3))
# KeyError((6, 1, 4))
# KeyError((6, 38, 2))
# KeyError((6, 38, 3))
# KeyError((6, 38, 4))
# KeyError((6, 38, 5))
# KeyError((6, 39, 1))
# KeyError((6, 39, 2))
# KeyError((6, 39, 3))
# KeyError((6, 39, 4))
# KeyError((6, 39, 5))
# KeyError((6, 40, 1))
# KeyError((6, 40, 2))
# KeyError((6, 40, 3))
# KeyError((6, 40, 4))
# KeyError((6, 40, 5))
# KeyError((6, 41, 1))
# KeyError((6, 41, 2))
# KeyError((6, 41, 3))
# KeyError((6, 41, 4))
# KeyError((6, 41, 5))
# KeyError((6, 42, 1))
# KeyError((6, 42, 2))
# KeyError((6, 42, 3))
# KeyError((6, 42, 4))
# KeyError((6, 42, 5))
# KeyError((6, 43, 1))
# KeyError((6, 43, 2))
# KeyError((6, 43, 3))
# KeyError((6, 43, 4))
# KeyError((6, 43, 5))
# KeyError((6, 44, 1))
# KeyError((6, 44, 2))
# KeyError((6, 44, 3))
# KeyError((6, 44, 4))
# KeyError((6, 44, 5))
# KeyError((6, 45, 1))
# KeyError((6, 45, 2))
# KeyError((6, 45, 3))
# KeyError((6, 45, 4))
# KeyError((6, 45, 5))
# KeyError((6, 46, 1))
# KeyError((6, 46, 2))
# KeyError((6, 46, 3))
# KeyError((6, 46, 4))
# KeyError((6, 46, 5))
# KeyError((6, 47, 1))
# KeyError((6, 47, 2))
# KeyError((6, 47, 3))
# KeyError((6, 47, 4))
# KeyError((6, 47, 5))
# KeyError((6, 48, 1))
# KeyError((6, 48, 2))
# KeyError((6, 48, 3))
# KeyError((6, 48, 4))
# KeyError((6, 48, 5))
# KeyError((6, 49, 1))
# KeyError((6, 49, 2))
# KeyError((6, 49, 3))
# KeyError((6, 49, 4))
# KeyError((6, 49, 5))
# KeyError((6, 50, 1))
# KeyError((6, 50, 2))
# KeyError((6, 50, 3))
# KeyError((6, 50, 4))
# KeyError((6, 50, 5))
# KeyError((6, 51, 1))
# KeyError((6, 51, 2))
# KeyError((6, 51, 3))
# KeyError((6, 51, 4))
# KeyError((6, 51, 5))
# KeyError((6, 52, 1))
# KeyError((6, 52, 2))
# KeyError((6, 52, 3))
# KeyError((6, 52, 4))
# KeyError((6, 52, 5))
# KeyError((7, 1, 1))
# KeyError((7, 44, 3))
# KeyError((7, 44, 4))
# KeyError((7, 44, 5))
# KeyError((7, 45, 1))
# KeyError((7, 45, 2))
# KeyError((7, 45, 3))
# KeyError((7, 45, 4))
# KeyError((7, 45, 5))
# KeyError((7, 46, 1))
# KeyError((7, 46, 2))
# KeyError((7, 46, 3))
# KeyError((7, 46, 4))
# KeyError((7, 46, 5))
# KeyError((7, 47, 1))
# KeyError((7, 47, 2))
# KeyError((7, 47, 3))
# KeyError((7, 47, 4))
# KeyError((7, 47, 5))
# KeyError((7, 48, 1))
# KeyError((7, 48, 2))
# KeyError((7, 48, 3))
# KeyError((7, 48, 4))
# KeyError((7, 48, 5))
# KeyError((7, 49, 1))
# KeyError((7, 49, 2))
# KeyError((7, 49, 3))
# KeyError((7, 49, 4))
# KeyError((7, 49, 5))
# KeyError((7, 50, 1))
# KeyError((7, 50, 2))
# KeyError((7, 50, 3))
# KeyError((7, 50, 4))
# KeyError((7, 50, 5))
# KeyError((7, 51, 1))
# KeyError((7, 51, 2))
# KeyError((7, 51, 3))
# KeyError((7, 51, 4))
# KeyError((7, 51, 5))
# KeyError((7, 52, 1))
# KeyError((7, 52, 2))
# KeyError((7, 52, 3))
# KeyError((7, 52, 4))
# KeyError((7, 52, 5))
# KeyError((8, 1, 1))
# KeyError((8, 1, 2))
# KeyError((8, 45, 4))
# KeyError((8, 45, 5))
# KeyError((8, 46, 1))
# KeyError((8, 46, 2))
# KeyError((8, 46, 3))
# KeyError((8, 46, 4))
# KeyError((8, 46, 5))
# KeyError((8, 47, 1))
# KeyError((8, 47, 2))
# KeyError((8, 47, 3))
# KeyError((8, 47, 4))
# KeyError((8, 47, 5))
# KeyError((8, 48, 1))
# KeyError((8, 48, 2))
# KeyError((8, 48, 3))
# KeyError((8, 48, 4))
# KeyError((8, 48, 5))
# KeyError((8, 49, 1))
# KeyError((8, 49, 2))
# KeyError((8, 49, 3))
# KeyError((8, 49, 4))
# KeyError((8, 49, 5))
# KeyError((8, 50, 1))
# KeyError((8, 50, 2))
# KeyError((8, 50, 3))
# KeyError((8, 50, 4))
# KeyError((8, 50, 5))
# KeyError((8, 51, 1))
# KeyError((8, 51, 2))
# KeyError((8, 51, 3))
# KeyError((8, 51, 4))
# KeyError((8, 51, 5))
# KeyError((8, 52, 1))
# KeyError((8, 52, 2))
# KeyError((8, 52, 3))
# KeyError((8, 52, 4))
# KeyError((8, 52, 5))
# KeyError((9, 1, 1))
# KeyError((9, 1, 2))
# KeyError((9, 1, 3))
# KeyError((9, 1, 4))
# KeyError((9, 43, 2))
# KeyError((9, 43, 3))
# KeyError((9, 43, 4))
# KeyError((9, 43, 5))
# KeyError((9, 44, 1))
# KeyError((9, 44, 2))
# KeyError((9, 44, 3))
# KeyError((9, 44, 4))
# KeyError((9, 44, 5))
# KeyError((9, 45, 1))
# KeyError((9, 45, 2))
# KeyError((9, 45, 3))
# KeyError((9, 45, 4))
# KeyError((9, 45, 5))
# KeyError((9, 46, 1))
# KeyError((9, 46, 2))
# KeyError((9, 46, 3))
# KeyError((9, 46, 4))
# KeyError((9, 46, 5))
# KeyError((9, 47, 1))
# KeyError((9, 47, 2))
# KeyError((9, 47, 3))
# KeyError((9, 47, 4))
# KeyError((9, 47, 5))
# KeyError((9, 48, 1))
# KeyError((9, 48, 2))
# KeyError((9, 48, 3))
# KeyError((9, 48, 4))
# KeyError((9, 48, 5))
# KeyError((9, 49, 1))
# KeyError((9, 49, 2))
# KeyError((9, 49, 3))
# KeyError((9, 49, 4))
# KeyError((9, 49, 5))
# KeyError((9, 50, 1))
# KeyError((9, 50, 2))
# KeyError((9, 50, 3))
# KeyError((9, 50, 4))
# KeyError((9, 50, 5))
# KeyError((9, 51, 1))
# KeyError((9, 51, 2))
# KeyError((9, 51, 3))
# KeyError((9, 51, 4))
# KeyError((9, 51, 5))
# KeyError((9, 52, 1))
# KeyError((9, 52, 2))
# KeyError((9, 52, 3))
# KeyError((9, 52, 4))
# KeyError((9, 52, 5))
# KeyError((10, 1, 1))
# KeyError((10, 44, 2))
# KeyError((10, 44, 3))
# KeyError((10, 44, 4))
# KeyError((10, 44, 5))
# KeyError((10, 45, 1))
# KeyError((10, 45, 2))
# KeyError((10, 45, 3))
# KeyError((10, 45, 4))
# KeyError((10, 45, 5))
# KeyError((10, 46, 1))
# KeyError((10, 46, 2))
# KeyError((10, 46, 3))
# KeyError((10, 46, 4))
# KeyError((10, 46, 5))
# KeyError((10, 47, 1))
# KeyError((10, 47, 2))
# KeyError((10, 47, 3))
# KeyError((10, 47, 4))
# KeyError((10, 47, 5))
# KeyError((10, 48, 1))
# KeyError((10, 48, 2))
# KeyError((10, 48, 3))
# KeyError((10, 48, 4))
# KeyError((10, 48, 5))
# KeyError((10, 49, 1))
# KeyError((10, 49, 2))
# KeyError((10, 49, 3))
# KeyError((10, 49, 4))
# KeyError((10, 49, 5))
# KeyError((10, 50, 1))
# KeyError((10, 50, 2))
# KeyError((10, 50, 3))
# KeyError((10, 50, 4))
# KeyError((10, 50, 5))
# KeyError((10, 51, 1))
# KeyError((10, 51, 2))
# KeyError((10, 51, 3))
# KeyError((10, 51, 4))
# KeyError((10, 51, 5))
# KeyError((10, 52, 1))
# KeyError((10, 52, 2))
# KeyError((10, 52, 3))
# KeyError((10, 52, 4))
# KeyError((10, 52, 5))
# KeyError((11, 1, 1))
# KeyError((11, 1, 2))
# KeyError((11, 1, 3))
# KeyError((11, 1, 4))
# KeyError((11, 45, 5))
# KeyError((11, 46, 1))
# KeyError((11, 46, 2))
# KeyError((11, 46, 3))
# KeyError((11, 46, 4))
# KeyError((11, 46, 5))
# KeyError((11, 47, 1))
# KeyError((11, 47, 2))
# KeyError((11, 47, 3))
# KeyError((11, 47, 4))
# KeyError((11, 47, 5))
# KeyError((11, 48, 1))
# KeyError((11, 48, 2))
# KeyError((11, 48, 3))
# KeyError((11, 48, 4))
# KeyError((11, 48, 5))
# KeyError((11, 49, 1))
# KeyError((11, 49, 2))
# KeyError((11, 49, 3))
# KeyError((11, 49, 4))
# KeyError((11, 49, 5))
# KeyError((11, 50, 1))
# KeyError((11, 50, 2))
# KeyError((11, 50, 3))
# KeyError((11, 50, 4))
# KeyError((11, 50, 5))
# KeyError((11, 51, 1))
# KeyError((11, 51, 2))
# KeyError((11, 51, 3))
# KeyError((11, 51, 4))
# KeyError((11, 51, 5))
# KeyError((11, 52, 1))
# KeyError((11, 52, 2))
# KeyError((11, 52, 3))
# KeyError((11, 52, 4))
# KeyError((11, 52, 5))
# KeyError((12, 1, 1))
# KeyError((12, 1, 2))
# KeyError((12, 1, 3))
# KeyError((12, 50, 3))
# KeyError((12, 50, 4))
# KeyError((12, 50, 5))
# KeyError((12, 51, 1))
# KeyError((12, 51, 2))
# KeyError((12, 51, 3))
# KeyError((12, 51, 4))
# KeyError((12, 51, 5))
# KeyError((12, 52, 1))
# KeyError((12, 52, 2))
# KeyError((12, 52, 3))
# KeyError((12, 52, 4))
# KeyError((12, 52, 5))
# KeyError((13, 1, 1))
# KeyError((13, 37, 5))
# KeyError((13, 38, 1))
# KeyError((13, 38, 2))
# KeyError((13, 38, 3))
# KeyError((13, 38, 4))
# KeyError((13, 38, 5))
# KeyError((13, 39, 1))
# KeyError((13, 39, 2))
# KeyError((13, 39, 3))
# KeyError((13, 39, 4))
# KeyError((13, 39, 5))
# KeyError((13, 40, 1))
# KeyError((13, 40, 2))
# KeyError((13, 40, 3))
# KeyError((13, 40, 4))
# KeyError((13, 40, 5))
# KeyError((13, 41, 1))
# KeyError((13, 41, 2))
# KeyError((13, 41, 3))
# KeyError((13, 41, 4))
# KeyError((13, 41, 5))
# KeyError((13, 42, 1))
# KeyError((13, 42, 2))
# KeyError((13, 42, 3))
# KeyError((13, 42, 4))
# KeyError((13, 42, 5))
# KeyError((13, 43, 1))
# KeyError((13, 43, 2))
# KeyError((13, 43, 3))
# KeyError((13, 43, 4))
# KeyError((13, 43, 5))
# KeyError((13, 44, 1))
# KeyError((13, 44, 2))
# KeyError((13, 44, 3))
# KeyError((13, 44, 4))
# KeyError((13, 44, 5))
# KeyError((13, 45, 1))
# KeyError((13, 45, 2))
# KeyError((13, 45, 3))
# KeyError((13, 45, 4))
# KeyError((13, 45, 5))
# KeyError((13, 46, 1))
# KeyError((13, 46, 2))
# KeyError((13, 46, 3))
# KeyError((13, 46, 4))
# KeyError((13, 46, 5))
# KeyError((13, 47, 1))
# KeyError((13, 47, 2))
# KeyError((13, 47, 3))
# KeyError((13, 47, 4))
# KeyError((13, 47, 5))
# KeyError((13, 48, 1))
# KeyError((13, 48, 2))
# KeyError((13, 48, 3))
# KeyError((13, 48, 4))
# KeyError((13, 48, 5))
# KeyError((13, 49, 1))
# KeyError((13, 49, 2))
# KeyError((13, 49, 3))
# KeyError((13, 49, 4))
# KeyError((13, 49, 5))
# KeyError((13, 50, 1))
# KeyError((13, 50, 2))
# KeyError((13, 50, 3))
# KeyError((13, 50, 4))
# KeyError((13, 50, 5))
# KeyError((13, 51, 1))
# KeyError((13, 51, 2))
# KeyError((13, 51, 3))
# KeyError((13, 51, 4))
# KeyError((13, 51, 5))
# KeyError((13, 52, 1))
# KeyError((13, 52, 2))
# KeyError((13, 52, 3))
# KeyError((13, 52, 4))
# KeyError((13, 52, 5))
# KeyError((14, 1, 1))
# KeyError((14, 1, 2))
# KeyError((14, 1, 3))
# KeyError((14, 1, 4))
# KeyError((14, 43, 5))
# KeyError((14, 44, 1))
# KeyError((14, 44, 2))
# KeyError((14, 44, 3))
# KeyError((14, 44, 4))
# KeyError((14, 44, 5))
# KeyError((14, 45, 1))
# KeyError((14, 45, 2))
# KeyError((14, 45, 3))
# KeyError((14, 45, 4))
# KeyError((14, 45, 5))
# KeyError((14, 46, 1))
# KeyError((14, 46, 2))
# KeyError((14, 46, 3))
# KeyError((14, 46, 4))
# KeyError((14, 46, 5))
# KeyError((14, 47, 1))
# KeyError((14, 47, 2))
# KeyError((14, 47, 3))
# KeyError((14, 47, 4))
# KeyError((14, 47, 5))
# KeyError((14, 48, 1))
# KeyError((14, 48, 2))
# KeyError((14, 48, 3))
# KeyError((14, 48, 4))
# KeyError((14, 48, 5))
# KeyError((14, 49, 1))
# KeyError((14, 49, 2))
# KeyError((14, 49, 3))
# KeyError((14, 49, 4))
# KeyError((14, 49, 5))
# KeyError((14, 50, 1))
# KeyError((14, 50, 2))
# KeyError((14, 50, 3))
# KeyError((14, 50, 4))
# KeyError((14, 50, 5))
# KeyError((14, 51, 1))
# KeyError((14, 51, 2))
# KeyError((14, 51, 3))
# KeyError((14, 51, 4))
# KeyError((14, 51, 5))
# KeyError((14, 52, 1))
# KeyError((14, 52, 2))
# KeyError((14, 52, 3))
# KeyError((14, 52, 4))
# KeyError((14, 52, 5))
# KeyError((15, 1, 1))
# KeyError((15, 52, 3))
# KeyError((15, 52, 4))
# KeyError((15, 52, 5))
# KeyError((16, 1, 1))
# KeyError((16, 1, 2))
# KeyError((16, 1, 3))
# KeyError((16, 41, 3))
# KeyError((16, 41, 4))
# KeyError((16, 41, 5))
# KeyError((16, 42, 1))
# KeyError((16, 42, 2))
# KeyError((16, 42, 3))
# KeyError((16, 42, 4))
# KeyError((16, 42, 5))
# KeyError((16, 43, 1))
# KeyError((16, 43, 2))
# KeyError((16, 43, 3))
# KeyError((16, 43, 4))
# KeyError((16, 43, 5))
# KeyError((16, 44, 1))
# KeyError((16, 44, 2))
# KeyError((16, 44, 3))
# KeyError((16, 44, 4))
# KeyError((16, 44, 5))
# KeyError((16, 45, 1))
# KeyError((16, 45, 2))
# KeyError((16, 45, 3))
# KeyError((16, 45, 4))
# KeyError((16, 45, 5))
# KeyError((16, 46, 1))
# KeyError((16, 46, 2))
# KeyError((16, 46, 3))
# KeyError((16, 46, 4))
# KeyError((16, 46, 5))
# KeyError((16, 47, 1))
# KeyError((16, 47, 2))
# KeyError((16, 47, 3))
# KeyError((16, 47, 4))
# KeyError((16, 47, 5))
# KeyError((16, 48, 1))
# KeyError((16, 48, 2))
# KeyError((16, 48, 3))
# KeyError((16, 48, 4))
# KeyError((16, 48, 5))
# KeyError((16, 49, 1))
# KeyError((16, 49, 2))
# KeyError((16, 49, 3))
# KeyError((16, 49, 4))
# KeyError((16, 49, 5))
# KeyError((16, 50, 1))
# KeyError((16, 50, 2))
# KeyError((16, 50, 3))
# KeyError((16, 50, 4))
# KeyError((16, 50, 5))
# KeyError((16, 51, 1))
# KeyError((16, 51, 2))
# KeyError((16, 51, 3))
# KeyError((16, 51, 4))
# KeyError((16, 51, 5))
# KeyError((16, 52, 1))
# KeyError((16, 52, 2))
# KeyError((16, 52, 3))
# KeyError((16, 52, 4))
# KeyError((16, 52, 5))
# KeyError((17, 1, 1))
# KeyError((17, 1, 2))
# KeyError((17, 43, 3))
# KeyError((17, 43, 4))
# KeyError((17, 43, 5))
# KeyError((17, 44, 1))
# KeyError((17, 44, 2))
# KeyError((17, 44, 3))
# KeyError((17, 44, 4))
# KeyError((17, 44, 5))
# KeyError((17, 45, 1))
# KeyError((17, 45, 2))
# KeyError((17, 45, 3))
# KeyError((17, 45, 4))
# KeyError((17, 45, 5))
# KeyError((17, 46, 1))
# KeyError((17, 46, 2))
# KeyError((17, 46, 3))
# KeyError((17, 46, 4))
# KeyError((17, 46, 5))
# KeyError((17, 47, 1))
# KeyError((17, 47, 2))
# KeyError((17, 47, 3))
# KeyError((17, 47, 4))
# KeyError((17, 47, 5))
# KeyError((17, 48, 1))
# KeyError((17, 48, 2))
# KeyError((17, 48, 3))
# KeyError((17, 48, 4))
# KeyError((17, 48, 5))
# KeyError((17, 49, 1))
# KeyError((17, 49, 2))
# KeyError((17, 49, 3))
# KeyError((17, 49, 4))
# KeyError((17, 49, 5))
# KeyError((17, 50, 1))
# KeyError((17, 50, 2))
# KeyError((17, 50, 3))
# KeyError((17, 50, 4))
# KeyError((17, 50, 5))
# KeyError((17, 51, 1))
# KeyError((17, 51, 2))
# KeyError((17, 51, 3))
# KeyError((17, 51, 4))
# KeyError((17, 51, 5))
# KeyError((17, 52, 1))
# KeyError((17, 52, 2))
# KeyError((17, 52, 3))
# KeyError((17, 52, 4))
# KeyError((17, 52, 5))
# KeyError((18, 1, 1))
# KeyError((18, 1, 2))
# KeyError((18, 1, 3))
# KeyError((18, 43, 5))
# KeyError((18, 44, 1))
# KeyError((18, 44, 2))
# KeyError((18, 44, 3))
# KeyError((18, 44, 4))
# KeyError((18, 44, 5))
# KeyError((18, 45, 1))
# KeyError((18, 45, 2))
# KeyError((18, 45, 3))
# KeyError((18, 45, 4))
# KeyError((18, 45, 5))
# KeyError((18, 46, 1))
# KeyError((18, 46, 2))
# KeyError((18, 46, 3))
# KeyError((18, 46, 4))
# KeyError((18, 46, 5))
# KeyError((18, 47, 1))
# KeyError((18, 47, 2))
# KeyError((18, 47, 3))
# KeyError((18, 47, 4))
# KeyError((18, 47, 5))
# KeyError((18, 48, 1))
# KeyError((18, 48, 2))
# KeyError((18, 48, 3))
# KeyError((18, 48, 4))
# KeyError((18, 48, 5))
# KeyError((18, 49, 1))
# KeyError((18, 49, 2))
# KeyError((18, 49, 3))
# KeyError((18, 49, 4))
# KeyError((18, 49, 5))
# KeyError((18, 50, 1))
# KeyError((18, 50, 2))
# KeyError((18, 50, 3))
# KeyError((18, 50, 4))
# KeyError((18, 50, 5))
# KeyError((18, 51, 1))
# KeyError((18, 51, 2))
# KeyError((18, 51, 3))
# KeyError((18, 51, 4))
# KeyError((18, 51, 5))
# KeyError((18, 52, 1))
# KeyError((18, 52, 2))
# KeyError((18, 52, 3))
# KeyError((18, 52, 4))
# KeyError((18, 52, 5))
# KeyError((19, 1, 1))
# KeyError((19, 1, 2))
# KeyError((19, 1, 3))
# KeyError((19, 43, 4))
# KeyError((19, 43, 5))
# KeyError((19, 44, 1))
# KeyError((19, 44, 2))
# KeyError((19, 44, 3))
# KeyError((19, 44, 4))
# KeyError((19, 44, 5))
# KeyError((19, 45, 1))
# KeyError((19, 45, 2))
# KeyError((19, 45, 3))
# KeyError((19, 45, 4))
# KeyError((19, 45, 5))
# KeyError((19, 46, 1))
# KeyError((19, 46, 2))
# KeyError((19, 46, 3))
# KeyError((19, 46, 4))
# KeyError((19, 46, 5))
# KeyError((19, 47, 1))
# KeyError((19, 47, 2))
# KeyError((19, 47, 3))
# KeyError((19, 47, 4))
# KeyError((19, 47, 5))
# KeyError((19, 48, 1))
# KeyError((19, 48, 2))
# KeyError((19, 48, 3))
# KeyError((19, 48, 4))
# KeyError((19, 48, 5))
# KeyError((19, 49, 1))
# KeyError((19, 49, 2))
# KeyError((19, 49, 3))
# KeyError((19, 49, 4))
# KeyError((19, 49, 5))
# KeyError((19, 50, 1))
# KeyError((19, 50, 2))
# KeyError((19, 50, 3))
# KeyError((19, 50, 4))
# KeyError((19, 50, 5))
# KeyError((19, 51, 1))
# KeyError((19, 51, 2))
# KeyError((19, 51, 3))
# KeyError((19, 51, 4))
# KeyError((19, 51, 5))
# KeyError((19, 52, 1))
# KeyError((19, 52, 2))
# KeyError((19, 52, 3))
# KeyError((19, 52, 4))
# KeyError((19, 52, 5))
# KeyError((20, 1, 1))
# KeyError((20, 1, 2))
# KeyError((20, 48, 3))
# KeyError((20, 48, 4))
# KeyError((20, 48, 5))
# KeyError((20, 49, 1))
# KeyError((20, 49, 2))
# KeyError((20, 49, 3))
# KeyError((20, 49, 4))
# KeyError((20, 49, 5))
# KeyError((20, 50, 1))
# KeyError((20, 50, 2))
# KeyError((20, 50, 3))
# KeyError((20, 50, 4))
# KeyError((20, 50, 5))
# KeyError((20, 51, 1))
# KeyError((20, 51, 2))
# KeyError((20, 51, 3))
# KeyError((20, 51, 4))
# KeyError((20, 51, 5))
# KeyError((20, 52, 1))
# KeyError((20, 52, 2))
# KeyError((20, 52, 3))
# KeyError((20, 52, 4))
# KeyError((20, 52, 5))
# KeyError((21, 1, 1))
# KeyError((21, 1, 2))
# KeyError((21, 48, 3))
# KeyError((21, 48, 4))
# KeyError((21, 48, 5))
# KeyError((21, 49, 1))
# KeyError((21, 49, 2))
# KeyError((21, 49, 3))
# KeyError((21, 49, 4))
# KeyError((21, 49, 5))
# KeyError((21, 50, 1))
# KeyError((21, 50, 2))
# KeyError((21, 50, 3))
# KeyError((21, 50, 4))
# KeyError((21, 50, 5))
# KeyError((21, 51, 1))
# KeyError((21, 51, 2))
# KeyError((21, 51, 3))
# KeyError((21, 51, 4))
# KeyError((21, 51, 5))
# KeyError((21, 52, 1))
# KeyError((21, 52, 2))
# KeyError((21, 52, 3))
# KeyError((21, 52, 4))
# KeyError((21, 52, 5))
# KeyError((22, 1, 1))
# KeyError((22, 44, 1))
# KeyError((22, 44, 2))
# KeyError((22, 44, 3))
# KeyError((22, 44, 4))
# KeyError((22, 44, 5))
# KeyError((22, 45, 1))
# KeyError((22, 45, 2))
# KeyError((22, 45, 3))
# KeyError((22, 45, 4))
# KeyError((22, 45, 5))
# KeyError((22, 46, 1))
# KeyError((22, 46, 2))
# KeyError((22, 46, 3))
# KeyError((22, 46, 4))
# KeyError((22, 46, 5))
# KeyError((22, 47, 1))
# KeyError((22, 47, 2))
# KeyError((22, 47, 3))
# KeyError((22, 47, 4))
# KeyError((22, 47, 5))
# KeyError((22, 48, 1))
# KeyError((22, 48, 2))
# KeyError((22, 48, 3))
# KeyError((22, 48, 4))
# KeyError((22, 48, 5))
# KeyError((22, 49, 1))
# KeyError((22, 49, 2))
# KeyError((22, 49, 3))
# KeyError((22, 49, 4))
# KeyError((22, 49, 5))
# KeyError((22, 50, 1))
# KeyError((22, 50, 2))
# KeyError((22, 50, 3))
# KeyError((22, 50, 4))
# KeyError((22, 50, 5))
# KeyError((22, 51, 1))
# KeyError((22, 51, 2))
# KeyError((22, 51, 3))
# KeyError((22, 51, 4))
# KeyError((22, 51, 5))
# KeyError((22, 52, 1))
# KeyError((22, 52, 2))
# KeyError((22, 52, 3))
# KeyError((22, 52, 4))
# KeyError((22, 52, 5))
# KeyError((23, 1, 1))
# KeyError((23, 1, 2))
# KeyError((23, 1, 3))
# KeyError((23, 1, 4))
# KeyError((23, 46, 5))
# KeyError((23, 47, 1))
# KeyError((23, 47, 2))
# KeyError((23, 47, 3))
# KeyError((23, 47, 4))
# KeyError((23, 47, 5))
# KeyError((23, 48, 1))
# KeyError((23, 48, 2))
# KeyError((23, 48, 3))
# KeyError((23, 48, 4))
# KeyError((23, 48, 5))
# KeyError((23, 49, 1))
# KeyError((23, 49, 2))
# KeyError((23, 49, 3))
# KeyError((23, 49, 4))
# KeyError((23, 49, 5))
# KeyError((23, 50, 1))
# KeyError((23, 50, 2))
# KeyError((23, 50, 3))
# KeyError((23, 50, 4))
# KeyError((23, 50, 5))
# KeyError((23, 51, 1))
# KeyError((23, 51, 2))
# KeyError((23, 51, 3))
# KeyError((23, 51, 4))
# KeyError((23, 51, 5))
# KeyError((23, 52, 1))
# KeyError((23, 52, 2))
# KeyError((23, 52, 3))
# KeyError((23, 52, 4))
# KeyError((23, 52, 5))
# KeyError((24, 1, 1))
# KeyError((24, 1, 2))
# KeyError((24, 36, 3))
# KeyError((24, 36, 4))
# KeyError((24, 36, 5))
# KeyError((24, 37, 1))
# KeyError((24, 37, 2))
# KeyError((24, 37, 3))
# KeyError((24, 37, 4))
# KeyError((24, 37, 5))
# KeyError((24, 38, 1))
# KeyError((24, 38, 2))
# KeyError((24, 38, 3))
# KeyError((24, 38, 4))
# KeyError((24, 38, 5))
# KeyError((24, 39, 1))
# KeyError((24, 39, 2))
# KeyError((24, 39, 3))
# KeyError((24, 39, 4))
# KeyError((24, 39, 5))
# KeyError((24, 40, 1))
# KeyError((24, 40, 2))
# KeyError((24, 40, 3))
# KeyError((24, 40, 4))
# KeyError((24, 40, 5))
# KeyError((24, 41, 1))
# KeyError((24, 41, 2))
# KeyError((24, 41, 3))
# KeyError((24, 41, 4))
# KeyError((24, 41, 5))
# KeyError((24, 42, 1))
# KeyError((24, 42, 2))
# KeyError((24, 42, 3))
# KeyError((24, 42, 4))
# KeyError((24, 42, 5))
# KeyError((24, 43, 1))
# KeyError((24, 43, 2))
# KeyError((24, 43, 3))
# KeyError((24, 43, 4))
# KeyError((24, 43, 5))
# KeyError((24, 44, 1))
# KeyError((24, 44, 2))
# KeyError((24, 44, 3))
# KeyError((24, 44, 4))
# KeyError((24, 44, 5))
# KeyError((24, 45, 1))
# KeyError((24, 45, 2))
# KeyError((24, 45, 3))
# KeyError((24, 45, 4))
# KeyError((24, 45, 5))
# KeyError((24, 46, 1))
# KeyError((24, 46, 2))
# KeyError((24, 46, 3))
# KeyError((24, 46, 4))
# KeyError((24, 46, 5))
# KeyError((24, 47, 1))
# KeyError((24, 47, 2))
# KeyError((24, 47, 3))
# KeyError((24, 47, 4))
# KeyError((24, 47, 5))
# KeyError((24, 48, 1))
# KeyError((24, 48, 2))
# KeyError((24, 48, 3))
# KeyError((24, 48, 4))
# KeyError((24, 48, 5))
# KeyError((24, 49, 1))
# KeyError((24, 49, 2))
# KeyError((24, 49, 3))
# KeyError((24, 49, 4))
# KeyError((24, 49, 5))
# KeyError((24, 50, 1))
# KeyError((24, 50, 2))
# KeyError((24, 50, 3))
# KeyError((24, 50, 4))
# KeyError((24, 50, 5))
# KeyError((24, 51, 1))
# KeyError((24, 51, 2))
# KeyError((24, 51, 3))
# KeyError((24, 51, 4))
# KeyError((24, 51, 5))
# KeyError((24, 52, 1))
# KeyError((24, 52, 2))
# KeyError((24, 52, 3))
# KeyError((24, 52, 4))
# KeyError((24, 52, 5))
# KeyError((25, 1, 1))
# KeyError((25, 1, 2))
# KeyError((25, 46, 1))
# KeyError((25, 46, 2))
# KeyError((25, 46, 3))
# KeyError((25, 46, 4))
# KeyError((25, 46, 5))
# KeyError((25, 47, 1))
# KeyError((25, 47, 2))
# KeyError((25, 47, 3))
# KeyError((25, 47, 4))
# KeyError((25, 47, 5))
# KeyError((25, 48, 1))
# KeyError((25, 48, 2))
# KeyError((25, 48, 3))
# KeyError((25, 48, 4))
# KeyError((25, 48, 5))
# KeyError((25, 49, 1))
# KeyError((25, 49, 2))
# KeyError((25, 49, 3))
# KeyError((25, 49, 4))
# KeyError((25, 49, 5))
# KeyError((25, 50, 1))
# KeyError((25, 50, 2))
# KeyError((25, 50, 3))
# KeyError((25, 50, 4))
# KeyError((25, 50, 5))
# KeyError((25, 51, 1))
# KeyError((25, 51, 2))
# KeyError((25, 51, 3))
# KeyError((25, 51, 4))
# KeyError((25, 51, 5))
# KeyError((25, 52, 1))
# KeyError((25, 52, 2))
# KeyError((25, 52, 3))
# KeyError((25, 52, 4))
# KeyError((25, 52, 5))
# KeyError((26, 1, 1))
# KeyError((26, 1, 2))
# KeyError((26, 43, 5))
# KeyError((26, 44, 1))
# KeyError((26, 44, 2))
# KeyError((26, 44, 3))
# KeyError((26, 44, 4))
# KeyError((26, 44, 5))
# KeyError((26, 45, 1))
# KeyError((26, 45, 2))
# KeyError((26, 45, 3))
# KeyError((26, 45, 4))
# KeyError((26, 45, 5))
# KeyError((26, 46, 1))
# KeyError((26, 46, 2))
# KeyError((26, 46, 3))
# KeyError((26, 46, 4))
# KeyError((26, 46, 5))
# KeyError((26, 47, 1))
# KeyError((26, 47, 2))
# KeyError((26, 47, 3))
# KeyError((26, 47, 4))
# KeyError((26, 47, 5))
# KeyError((26, 48, 1))
# KeyError((26, 48, 2))
# KeyError((26, 48, 3))
# KeyError((26, 48, 4))
# KeyError((26, 48, 5))
# KeyError((26, 49, 1))
# KeyError((26, 49, 2))
# KeyError((26, 49, 3))
# KeyError((26, 49, 4))
# KeyError((26, 49, 5))
# KeyError((26, 50, 1))
# KeyError((26, 50, 2))
# KeyError((26, 50, 3))
# KeyError((26, 50, 4))
# KeyError((26, 50, 5))
# KeyError((26, 51, 1))
# KeyError((26, 51, 2))
# KeyError((26, 51, 3))
# KeyError((26, 51, 4))
# KeyError((26, 51, 5))
# KeyError((26, 52, 1))
# KeyError((26, 52, 2))
# KeyError((26, 52, 3))
# KeyError((26, 52, 4))
# KeyError((26, 52, 5))
# KeyError((27, 1, 1))
# KeyError((27, 43, 3))
# KeyError((27, 43, 4))
# KeyError((27, 43, 5))
# KeyError((27, 44, 1))
# KeyError((27, 44, 2))
# KeyError((27, 44, 3))
# KeyError((27, 44, 4))
# KeyError((27, 44, 5))
# KeyError((27, 45, 1))
# KeyError((27, 45, 2))
# KeyError((27, 45, 3))
# KeyError((27, 45, 4))
# KeyError((27, 45, 5))
# KeyError((27, 46, 1))
# KeyError((27, 46, 2))
# KeyError((27, 46, 3))
# KeyError((27, 46, 4))
# KeyError((27, 46, 5))
# KeyError((27, 47, 1))
# KeyError((27, 47, 2))
# KeyError((27, 47, 3))
# KeyError((27, 47, 4))
# KeyError((27, 47, 5))
# KeyError((27, 48, 1))
# KeyError((27, 48, 2))
# KeyError((27, 48, 3))
# KeyError((27, 48, 4))
# KeyError((27, 48, 5))
# KeyError((27, 49, 1))
# KeyError((27, 49, 2))
# KeyError((27, 49, 3))
# KeyError((27, 49, 4))
# KeyError((27, 49, 5))
# KeyError((27, 50, 1))
# KeyError((27, 50, 2))
# KeyError((27, 50, 3))
# KeyError((27, 50, 4))
# KeyError((27, 50, 5))
# KeyError((27, 51, 1))
# KeyError((27, 51, 2))
# KeyError((27, 51, 3))
# KeyError((27, 51, 4))
# KeyError((27, 51, 5))
# KeyError((27, 52, 1))
# KeyError((27, 52, 2))
# KeyError((27, 52, 3))
# KeyError((27, 52, 4))
# KeyError((27, 52, 5))
# KeyError((28, 1, 1))
# KeyError((28, 1, 2))
# KeyError((28, 1, 3))
# KeyError((28, 43, 4))
# KeyError((28, 43, 5))
# KeyError((28, 44, 1))
# KeyError((28, 44, 2))
# KeyError((28, 44, 3))
# KeyError((28, 44, 4))
# KeyError((28, 44, 5))
# KeyError((28, 45, 1))
# KeyError((28, 45, 2))
# KeyError((28, 45, 3))
# KeyError((28, 45, 4))
# KeyError((28, 45, 5))
# KeyError((28, 46, 1))
# KeyError((28, 46, 2))
# KeyError((28, 46, 3))
# KeyError((28, 46, 4))
# KeyError((28, 46, 5))
# KeyError((28, 47, 1))
# KeyError((28, 47, 2))
# KeyError((28, 47, 3))
# KeyError((28, 47, 4))
# KeyError((28, 47, 5))
# KeyError((28, 48, 1))
# KeyError((28, 48, 2))
# KeyError((28, 48, 3))
# KeyError((28, 48, 4))
# KeyError((28, 48, 5))
# KeyError((28, 49, 1))
# KeyError((28, 49, 2))
# KeyError((28, 49, 3))
# KeyError((28, 49, 4))
# KeyError((28, 49, 5))
# KeyError((28, 50, 1))
# KeyError((28, 50, 2))
# KeyError((28, 50, 3))
# KeyError((28, 50, 4))
# KeyError((28, 50, 5))
# KeyError((28, 51, 1))
# KeyError((28, 51, 2))
# KeyError((28, 51, 3))
# KeyError((28, 51, 4))
# KeyError((28, 51, 5))
# KeyError((28, 52, 1))
# KeyError((28, 52, 2))
# KeyError((28, 52, 3))
# KeyError((28, 52, 4))
# KeyError((28, 52, 5))
# KeyError((29, 1, 1))
# KeyError((29, 18, 5))
# KeyError((29, 19, 1))
# KeyError((29, 19, 2))
# KeyError((29, 19, 3))
# KeyError((29, 19, 4))
# KeyError((29, 19, 5))
# KeyError((29, 20, 1))
# KeyError((29, 20, 2))
# KeyError((29, 20, 3))
# KeyError((29, 20, 4))
# KeyError((29, 20, 5))
# KeyError((29, 21, 1))
# KeyError((29, 21, 2))
# KeyError((29, 21, 3))
# KeyError((29, 21, 4))
# KeyError((29, 21, 5))
# KeyError((29, 22, 1))
# KeyError((29, 22, 2))
# KeyError((29, 22, 3))
# KeyError((29, 22, 4))
# KeyError((29, 22, 5))
# KeyError((29, 23, 1))
# KeyError((29, 23, 2))
# KeyError((29, 23, 3))
# KeyError((29, 23, 4))
# KeyError((29, 23, 5))
# KeyError((29, 24, 1))
# KeyError((29, 24, 2))
# KeyError((29, 24, 3))
# KeyError((29, 24, 4))
# KeyError((29, 24, 5))
# KeyError((29, 25, 1))
# KeyError((29, 25, 2))
# KeyError((29, 25, 3))
# KeyError((29, 25, 4))
# KeyError((29, 25, 5))
# KeyError((29, 26, 1))
# KeyError((29, 26, 2))
# KeyError((29, 26, 3))
# KeyError((29, 26, 4))
# KeyError((29, 26, 5))
# KeyError((29, 27, 1))
# KeyError((29, 27, 2))
# KeyError((29, 27, 3))
# KeyError((29, 27, 4))
# KeyError((29, 27, 5))
# KeyError((29, 28, 1))
# KeyError((29, 28, 2))
# KeyError((29, 28, 3))
# KeyError((29, 28, 4))
# KeyError((29, 28, 5))
# KeyError((29, 29, 1))
# KeyError((29, 29, 2))
# KeyError((29, 29, 3))
# KeyError((29, 29, 4))
# KeyError((29, 29, 5))
# KeyError((29, 30, 1))
# KeyError((29, 30, 2))
# KeyError((29, 30, 3))
# KeyError((29, 30, 4))
# KeyError((29, 30, 5))
# KeyError((29, 31, 1))
# KeyError((29, 31, 2))
# KeyError((29, 31, 3))
# KeyError((29, 31, 4))
# KeyError((29, 31, 5))
# KeyError((29, 32, 1))
# KeyError((29, 32, 2))
# KeyError((29, 32, 3))
# KeyError((29, 32, 4))
# KeyError((29, 32, 5))
# KeyError((29, 33, 1))
# KeyError((29, 33, 2))
# KeyError((29, 33, 3))
# KeyError((29, 33, 4))
# KeyError((29, 33, 5))
# KeyError((29, 34, 1))
# KeyError((29, 34, 2))
# KeyError((29, 34, 3))
# KeyError((29, 34, 4))
# KeyError((29, 34, 5))
# KeyError((29, 35, 1))
# KeyError((29, 35, 2))
# KeyError((29, 35, 3))
# KeyError((29, 35, 4))
# KeyError((29, 35, 5))
# KeyError((29, 36, 1))
# KeyError((29, 36, 2))
# KeyError((29, 36, 3))
# KeyError((29, 36, 4))
# KeyError((29, 36, 5))
# KeyError((29, 37, 1))
# KeyError((29, 37, 2))
# KeyError((29, 37, 3))
# KeyError((29, 37, 4))
# KeyError((29, 37, 5))
# KeyError((29, 38, 1))
# KeyError((29, 38, 2))
# KeyError((29, 38, 3))
# KeyError((29, 38, 4))
# KeyError((29, 38, 5))
# KeyError((29, 39, 1))
# KeyError((29, 39, 2))
# KeyError((29, 39, 3))
# KeyError((29, 39, 4))
# KeyError((29, 39, 5))
# KeyError((29, 40, 1))
# KeyError((29, 40, 2))
# KeyError((29, 40, 3))
# KeyError((29, 40, 4))
# KeyError((29, 40, 5))
# KeyError((29, 41, 1))
# KeyError((29, 41, 2))
# KeyError((29, 41, 3))
# KeyError((29, 41, 4))
# KeyError((29, 41, 5))
# KeyError((29, 42, 1))
# KeyError((29, 42, 2))
# KeyError((29, 42, 3))
# KeyError((29, 42, 4))
# KeyError((29, 42, 5))
# KeyError((29, 43, 1))
# KeyError((29, 43, 2))
# KeyError((29, 43, 3))
# KeyError((29, 43, 4))
# KeyError((29, 43, 5))
# KeyError((29, 44, 1))
# KeyError((29, 44, 2))
# KeyError((29, 44, 3))
# KeyError((29, 44, 4))
# KeyError((29, 44, 5))
# KeyError((29, 45, 1))
# KeyError((29, 45, 2))
# KeyError((29, 45, 3))
# KeyError((29, 45, 4))
# KeyError((29, 45, 5))
# KeyError((29, 46, 1))
# KeyError((29, 46, 2))
# KeyError((29, 46, 3))
# KeyError((29, 46, 4))
# KeyError((29, 46, 5))
# KeyError((29, 47, 1))
# KeyError((29, 47, 2))
# KeyError((29, 47, 3))
# KeyError((29, 47, 4))
# KeyError((29, 47, 5))
# KeyError((29, 48, 1))
# KeyError((29, 48, 2))
# KeyError((29, 48, 3))
# KeyError((29, 48, 4))
# KeyError((29, 48, 5))
# KeyError((29, 49, 1))
# KeyError((29, 49, 2))
# KeyError((29, 49, 3))
# KeyError((29, 49, 4))
# KeyError((29, 49, 5))
# KeyError((29, 50, 1))
# KeyError((29, 50, 2))
# KeyError((29, 50, 3))
# KeyError((29, 50, 4))
# KeyError((29, 50, 5))
# KeyError((29, 51, 1))
# KeyError((29, 51, 2))
# KeyError((29, 51, 3))
# KeyError((29, 51, 4))
# KeyError((29, 51, 5))
# KeyError((29, 52, 1))
# KeyError((29, 52, 2))
# KeyError((29, 52, 3))
# KeyError((29, 52, 4))
# KeyError((29, 52, 5))
# KeyError((30, 1, 1))
# KeyError((30, 43, 2))
# KeyError((30, 43, 3))
# KeyError((30, 43, 4))
# KeyError((30, 43, 5))
# KeyError((30, 44, 1))
# KeyError((30, 44, 2))
# KeyError((30, 44, 3))
# KeyError((30, 44, 4))
# KeyError((30, 44, 5))
# KeyError((30, 45, 1))
# KeyError((30, 45, 2))
# KeyError((30, 45, 3))
# KeyError((30, 45, 4))
# KeyError((30, 45, 5))
# KeyError((30, 46, 1))
# KeyError((30, 46, 2))
# KeyError((30, 46, 3))
# KeyError((30, 46, 4))
# KeyError((30, 46, 5))
# KeyError((30, 47, 1))
# KeyError((30, 47, 2))
# KeyError((30, 47, 3))
# KeyError((30, 47, 4))
# KeyError((30, 47, 5))
# KeyError((30, 48, 1))
# KeyError((30, 48, 2))
# KeyError((30, 48, 3))
# KeyError((30, 48, 4))
# KeyError((30, 48, 5))
# KeyError((30, 49, 1))
# KeyError((30, 49, 2))
# KeyError((30, 49, 3))
# KeyError((30, 49, 4))
# KeyError((30, 49, 5))
# KeyError((30, 50, 1))
# KeyError((30, 50, 2))
# KeyError((30, 50, 3))
# KeyError((30, 50, 4))
# KeyError((30, 50, 5))
# KeyError((30, 51, 1))
# KeyError((30, 51, 2))
# KeyError((30, 51, 3))
# KeyError((30, 51, 4))
# KeyError((30, 51, 5))
# KeyError((30, 52, 1))
# KeyError((30, 52, 2))
# KeyError((30, 52, 3))
# KeyError((30, 52, 4))
# KeyError((30, 52, 5))
# KeyError((31, 1, 1))
# KeyError((31, 1, 2))
# KeyError((31, 1, 3))
# KeyError((31, 1, 4))
# KeyError((31, 38, 4))
# KeyError((31, 38, 5))
# KeyError((31, 39, 1))
# KeyError((31, 39, 2))
# KeyError((31, 39, 3))
# KeyError((31, 39, 4))
# KeyError((31, 39, 5))
# KeyError((31, 40, 1))
# KeyError((31, 40, 2))
# KeyError((31, 40, 3))
# KeyError((31, 40, 4))
# KeyError((31, 40, 5))
# KeyError((31, 41, 1))
# KeyError((31, 41, 2))
# KeyError((31, 41, 3))
# KeyError((31, 41, 4))
# KeyError((31, 41, 5))
# KeyError((31, 42, 1))
# KeyError((31, 42, 2))
# KeyError((31, 42, 3))
# KeyError((31, 42, 4))
# KeyError((31, 42, 5))
# KeyError((31, 43, 1))
# KeyError((31, 43, 2))
# KeyError((31, 43, 3))
# KeyError((31, 43, 4))
# KeyError((31, 43, 5))
# KeyError((31, 44, 1))
# KeyError((31, 44, 2))
# KeyError((31, 44, 3))
# KeyError((31, 44, 4))
# KeyError((31, 44, 5))
# KeyError((31, 45, 1))
# KeyError((31, 45, 2))
# KeyError((31, 45, 3))
# KeyError((31, 45, 4))
# KeyError((31, 45, 5))
# KeyError((31, 46, 1))
# KeyError((31, 46, 2))
# KeyError((31, 46, 3))
# KeyError((31, 46, 4))
# KeyError((31, 46, 5))
# KeyError((31, 47, 1))
# KeyError((31, 47, 2))
# KeyError((31, 47, 3))
# KeyError((31, 47, 4))
# KeyError((31, 47, 5))
# KeyError((31, 48, 1))
# KeyError((31, 48, 2))
# KeyError((31, 48, 3))
# KeyError((31, 48, 4))
# KeyError((31, 48, 5))
# KeyError((31, 49, 1))
# KeyError((31, 49, 2))
# KeyError((31, 49, 3))
# KeyError((31, 49, 4))
# KeyError((31, 49, 5))
# KeyError((31, 50, 1))
# KeyError((31, 50, 2))
# KeyError((31, 50, 3))
# KeyError((31, 50, 4))
# KeyError((31, 50, 5))
# KeyError((31, 51, 1))
# KeyError((31, 51, 2))
# KeyError((31, 51, 3))
# KeyError((31, 51, 4))
# KeyError((31, 51, 5))
# KeyError((31, 52, 1))
# KeyError((31, 52, 2))
# KeyError((31, 52, 3))
# KeyError((31, 52, 4))
# KeyError((31, 52, 5))
# KeyError((32, 1, 1))
# KeyError((32, 1, 2))
# KeyError((32, 1, 3))
# KeyError((32, 1, 4))
# KeyError((32, 46, 5))
# KeyError((32, 47, 1))
# KeyError((32, 47, 2))
# KeyError((32, 47, 3))
# KeyError((32, 47, 4))
# KeyError((32, 47, 5))
# KeyError((32, 48, 1))
# KeyError((32, 48, 2))
# KeyError((32, 48, 3))
# KeyError((32, 48, 4))
# KeyError((32, 48, 5))
# KeyError((32, 49, 1))
# KeyError((32, 49, 2))
# KeyError((32, 49, 3))
# KeyError((32, 49, 4))
# KeyError((32, 49, 5))
# KeyError((32, 50, 1))
# KeyError((32, 50, 2))
# KeyError((32, 50, 3))
# KeyError((32, 50, 4))
# KeyError((32, 50, 5))
# KeyError((32, 51, 1))
# KeyError((32, 51, 2))
# KeyError((32, 51, 3))
# KeyError((32, 51, 4))
# KeyError((32, 51, 5))
# KeyError((32, 52, 1))
# KeyError((32, 52, 2))
# KeyError((32, 52, 3))
# KeyError((32, 52, 4))
# KeyError((32, 52, 5))
# KeyError((33, 1, 1))
# KeyError((33, 46, 5))
# KeyError((33, 47, 1))
# KeyError((33, 47, 2))
# KeyError((33, 47, 3))
# KeyError((33, 47, 4))
# KeyError((33, 47, 5))
# KeyError((33, 48, 1))
# KeyError((33, 48, 2))
# KeyError((33, 48, 3))
# KeyError((33, 48, 4))
# KeyError((33, 48, 5))
# KeyError((33, 49, 1))
# KeyError((33, 49, 2))
# KeyError((33, 49, 3))
# KeyError((33, 49, 4))
# KeyError((33, 49, 5))
# KeyError((33, 50, 1))
# KeyError((33, 50, 2))
# KeyError((33, 50, 3))
# KeyError((33, 50, 4))
# KeyError((33, 50, 5))
# KeyError((33, 51, 1))
# KeyError((33, 51, 2))
# KeyError((33, 51, 3))
# KeyError((33, 51, 4))
# KeyError((33, 51, 5))
# KeyError((33, 52, 1))
# KeyError((33, 52, 2))
# KeyError((33, 52, 3))
# KeyError((33, 52, 4))
# KeyError((33, 52, 5))
# KeyError((34, 1, 1))
# KeyError((34, 1, 2))
# KeyError((34, 1, 3))
# KeyError((34, 44, 1))
# KeyError((34, 44, 2))
# KeyError((34, 44, 3))
# KeyError((34, 44, 4))
# KeyError((34, 44, 5))
# KeyError((34, 45, 1))
# KeyError((34, 45, 2))
# KeyError((34, 45, 3))
# KeyError((34, 45, 4))
# KeyError((34, 45, 5))
# KeyError((34, 46, 1))
# KeyError((34, 46, 2))
# KeyError((34, 46, 3))
# KeyError((34, 46, 4))
# KeyError((34, 46, 5))
# KeyError((34, 47, 1))
# KeyError((34, 47, 2))
# KeyError((34, 47, 3))
# KeyError((34, 47, 4))
# KeyError((34, 47, 5))
# KeyError((34, 48, 1))
# KeyError((34, 48, 2))
# KeyError((34, 48, 3))
# KeyError((34, 48, 4))
# KeyError((34, 48, 5))
# KeyError((34, 49, 1))
# KeyError((34, 49, 2))
# KeyError((34, 49, 3))
# KeyError((34, 49, 4))
# KeyError((34, 49, 5))
# KeyError((34, 50, 1))
# KeyError((34, 50, 2))
# KeyError((34, 50, 3))
# KeyError((34, 50, 4))
# KeyError((34, 50, 5))
# KeyError((34, 51, 1))
# KeyError((34, 51, 2))
# KeyError((34, 51, 3))
# KeyError((34, 51, 4))
# KeyError((34, 51, 5))
# KeyError((34, 52, 1))
# KeyError((34, 52, 2))
# KeyError((34, 52, 3))
# KeyError((34, 52, 4))
# KeyError((34, 52, 5))
# KeyError((35, 1, 1))
# KeyError((35, 43, 5))
# KeyError((35, 44, 1))
# KeyError((35, 44, 2))
# KeyError((35, 44, 3))
# KeyError((35, 44, 4))
# KeyError((35, 44, 5))
# KeyError((35, 45, 1))
# KeyError((35, 45, 2))
# KeyError((35, 45, 3))
# KeyError((35, 45, 4))
# KeyError((35, 45, 5))
# KeyError((35, 46, 1))
# KeyError((35, 46, 2))
# KeyError((35, 46, 3))
# KeyError((35, 46, 4))
# KeyError((35, 46, 5))
# KeyError((35, 47, 1))
# KeyError((35, 47, 2))
# KeyError((35, 47, 3))
# KeyError((35, 47, 4))
# KeyError((35, 47, 5))
# KeyError((35, 48, 1))
# KeyError((35, 48, 2))
# KeyError((35, 48, 3))
# KeyError((35, 48, 4))
# KeyError((35, 48, 5))
# KeyError((35, 49, 1))
# KeyError((35, 49, 2))
# KeyError((35, 49, 3))
# KeyError((35, 49, 4))
# KeyError((35, 49, 5))
# KeyError((35, 50, 1))
# KeyError((35, 50, 2))
# KeyError((35, 50, 3))
# KeyError((35, 50, 4))
# KeyError((35, 50, 5))
# KeyError((35, 51, 1))
# KeyError((35, 51, 2))
# KeyError((35, 51, 3))
# KeyError((35, 51, 4))
# KeyError((35, 51, 5))
# KeyError((35, 52, 1))
# KeyError((35, 52, 2))
# KeyError((35, 52, 3))
# KeyError((35, 52, 4))
# KeyError((35, 52, 5))
# KeyError((36, 1, 1))
# KeyError((36, 1, 2))
# KeyError((36, 41, 5))
# KeyError((36, 42, 1))
# KeyError((36, 42, 2))
# KeyError((36, 42, 3))
# KeyError((36, 42, 4))
# KeyError((36, 42, 5))
# KeyError((36, 43, 1))
# KeyError((36, 43, 2))
# KeyError((36, 43, 3))
# KeyError((36, 43, 4))
# KeyError((36, 43, 5))
# KeyError((36, 44, 1))
# KeyError((36, 44, 2))
# KeyError((36, 44, 3))
# KeyError((36, 44, 4))
# KeyError((36, 44, 5))
# KeyError((36, 45, 1))
# KeyError((36, 45, 2))
# KeyError((36, 45, 3))
# KeyError((36, 45, 4))
# KeyError((36, 45, 5))
# KeyError((36, 46, 1))
# KeyError((36, 46, 2))
# KeyError((36, 46, 3))
# KeyError((36, 46, 4))
# KeyError((36, 46, 5))
# KeyError((36, 47, 1))
# KeyError((36, 47, 2))
# KeyError((36, 47, 3))
# KeyError((36, 47, 4))
# KeyError((36, 47, 5))
# KeyError((36, 48, 1))
# KeyError((36, 48, 2))
# KeyError((36, 48, 3))
# KeyError((36, 48, 4))
# KeyError((36, 48, 5))
# KeyError((36, 49, 1))
# KeyError((36, 49, 2))
# KeyError((36, 49, 3))
# KeyError((36, 49, 4))
# KeyError((36, 49, 5))
# KeyError((36, 50, 1))
# KeyError((36, 50, 2))
# KeyError((36, 50, 3))
# KeyError((36, 50, 4))
# KeyError((36, 50, 5))
# KeyError((36, 51, 1))
# KeyError((36, 51, 2))
# KeyError((36, 51, 3))
# KeyError((36, 51, 4))
# KeyError((36, 51, 5))
# KeyError((36, 52, 1))
# KeyError((36, 52, 2))
# KeyError((36, 52, 3))
# KeyError((36, 52, 4))
# KeyError((36, 52, 5))
# KeyError((37, 1, 1))
# KeyError((37, 1, 2))
# KeyError((37, 1, 3))
# KeyError((37, 1, 4))
# KeyError((37, 47, 5))
# KeyError((37, 48, 1))
# KeyError((37, 48, 2))
# KeyError((37, 48, 3))
# KeyError((37, 48, 4))
# KeyError((37, 48, 5))
# KeyError((37, 49, 1))
# KeyError((37, 49, 2))
# KeyError((37, 49, 3))
# KeyError((37, 49, 4))
# KeyError((37, 49, 5))
# KeyError((37, 50, 1))
# KeyError((37, 50, 2))
# KeyError((37, 50, 3))
# KeyError((37, 50, 4))
# KeyError((37, 50, 5))
# KeyError((37, 51, 1))
# KeyError((37, 51, 2))
# KeyError((37, 51, 3))
# KeyError((37, 51, 4))
# KeyError((37, 51, 5))
# KeyError((37, 52, 1))
# KeyError((37, 52, 2))
# KeyError((37, 52, 3))
# KeyError((37, 52, 4))
# KeyError((37, 52, 5))

# %%
from matplotlib.pyplot import matshow
matshow(A_hs, aspect = 'auto')

# %%
np.save(os.path.join(output_dir, "heartsteps_mask.npy"), A_hs)
np.save(os.path.join(output_dir, "heartsteps_data.npy"), M_hs)

# %% [markdown]
# ## Unused code

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
  display(df_merged_cut[df_merged_cut['user.index'] == 4].iloc[1600:1680])

# %%
idx = df_merged.index.get_indexer_for(df_merged[pd.notna(df_merged["avail"])].index)
trial = df_merged.iloc[idx].reset_index(drop = True)
trial

# %%
trial_sel = trial[["user.index", "decision.index.nogap", "sugg.select.utime", "sugg.decision.utime", "sugg.select.slot", "avail", "send", "send.active", "send.sedentary"]]
trial_sel

# %%
# df_sugg_sel

# %%
# out = pd.merge(trial_sel, df_sugg_sel, on=['user.index', 'sugg.select.utime'], how='outer',
#                suffixes=('_df1', '_df2')).set_index(['user.index', 'sugg.select.utime'])

# out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)) \
#                            .swaplevel()

# out = out['df1'].compare(out['df2'])

out
